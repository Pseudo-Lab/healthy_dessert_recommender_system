# %%
import pandas as pd
from konlpy.tag import Okt
from numpy import ndarray
import warnings
import re 
from model.bow import BagOfWords
from model.tfidf import TfIdf
import yaml
warnings.filterwarnings("ignore")

# %%
# config
with open('configs/database.yaml') as f:
    cfg = yaml.load(f, Loader=yaml.FullLoader)

# %%
from utils.query_service import QueryService
query_service = QueryService(cfg['mysql'])

# %%
query_service.query_to_pandas_df('Show tables')
# Out:
#               Tables_in_bakery
# 0   board_preference_statistic
# 1              board_statistic
# 2                  food_survey
# 3                        image
# 4                       member
# 5            member_preference
# 6                       notice
# 7                   preference
# 8                      product
# 9                product_board
# 10              product_detail
# 11                 product_img
# 12                        push
# 13                   push_date
# 14                random_board
# 15               refresh_token
# 16                      review
# 17                  review_img
# 18                 review_like
# 19                      search
# 20         signature_agreement
# 21                       store
# 22                  test_store
# 23             wishlist_folder
# 24            wishlist_product
# 25              wishlist_store
# 26                  withdrawal

# %%
PRODUCT_BOARD_SQL = """
SELECT id
, store_id
, title
, price
, is_soldout
, view 
FROM product_board
"""
product_board = query_service.query_to_pandas_df(PRODUCT_BOARD_SQL)

# %%
PRODUCT_SQL = """
SELECT id
, product_board_id
, title as option
, price as option_price
, category
, gluten_free_tag
, high_protein_tag
, sugar_free_tag
, vegan_tag
, ketogenic_tag
FROM product
"""
product = query_service.quaery_to_pandas_df(PRODUCT_SQL)

# %%
REVIEW_SQL = """
SELECT board_id
, badge_taste
, badge_brix
, badge_texture
, rate
, content
FROM review
"""
review = query_service.query_to_pandas_df(REVIEW_SQL)
review = review.drop_duplicates(subset=['board_id', 'content'], keep='first')

# %%
BOARD_STAT_SQL = """
SELECT board_id
, board_review_grade
, board_view_count
, board_review_count
, board_wish_count 
FROM board_statistic
"""
board_stat = query_service.query_to_pandas_df(BOARD_STAT_SQL)

# %%
# board_id가 각 preference_type마다 얼만큼의 preference_score를 갖는지
# 아직 신뢰성있는 데이터로 보이진 않음 (샘플이 적고 score의 분산이 너무 큼)
BOARD_PREFERENCE_STAT_SQL = """
SELECT board_id
, preference_score
, preference_type
, preference_weight
FROM board_preference_statistic
ORDER BY board_id
"""
board_preference_stat = query_service.query_to_pandas_df(BOARD_PREFERENCE_STAT_SQL)

# %% [markdown]
# #### Data Import

# %%
df = pd.read_csv('data/product_board_feature.csv', encoding='utf-8')

# %%
# NLP 
okt = Okt()
def tokenize(text):
    return ['/'.join(t) for t in okt.pos(text, norm=True, stem=True)]

# 자연어 데이터만 추출
nl_df = df[['id', 'title', 'flavor']]

# %%
nl_df['title'] = nl_df['title'].astype(str)
nl_df['flavor'] = nl_df['flavor'].astype(str)

# %% [markdown]
# #### Preprocessing

# %%
# 소문자로 변환
nl_df['title'] = nl_df['title'].str.lower()
nl_df['flavor'] = nl_df['flavor'].str.lower()

# %%
# 특수문자 제거
special_chars = '[^가-힣0-9a-zA-Z]'
nl_df['title'] = nl_df['title'].apply(lambda x: re.sub(special_chars, ' ', x))
nl_df['flavor'] = nl_df['flavor'].apply(lambda x: re.sub(special_chars, ' ', x))

# %%
# preprocessing Rule
# 목적 : token이 될 수 있는 유효한 단어만 남기기 위해 불필요한 단어의 종류를 정의하고 제거한다.
# 수량 제거
quantity_compiler = re.compile(r'\d+[개입|kg|팩|개|종|입|원|g]+')
nl_df['title'] = nl_df['title'].apply(lambda x: re.sub(quantity_compiler, ' ', x))
nl_df['flavor'] = nl_df['flavor'].apply(lambda x: re.sub(quantity_compiler, ' ', x))

# %%
# title과 option을 합쳐서 description을 만든다.
nl_df['description'] = nl_df['title'] + ' ' + nl_df['flavor']

# %%
# tokenizing
nl_df['token'] = nl_df['description'].apply(lambda x: okt.morphs(x))

# %%
# 중복 단어 제거 : 나열식의 중복 단어가 노이즈로 인식됨 
nl_df['token'] = nl_df['token'].apply(lambda x: list(set(x)))

# %%
# stopwords 제거
with open('data/stopwords.txt', 'r', encoding='utf-8') as f:
    stopwords = f.readlines()
    stopwords = [x.strip() for x in stopwords]
nl_df['token'] = nl_df['token'].apply(lambda x: [word for word in x if word not in stopwords])

# %%
# description mutation : 
nl_df['description'] = nl_df['token'].apply(lambda x: ' '.join(x))

# %%
# id2idx
id2idx = {id:idx for idx, id in enumerate(nl_df['id'])}
idx2id = {idx:id for idx, id in enumerate(nl_df['id'])}

# %%
board_id_2_store_id = {board_id:store_id for board_id, store_id in zip(df['id'], df['store_id'])}

# %% [markdown]
# #### Fit
# - 현재 있는 모델은 tfidf, bow입니다.
# - 아래의 예시처럼 model.fit()에 description 컬럼을 넣는다고 생각하시면 됩니다.

# %%
tfidf = TfIdf()
tfidf.fit(nl_df['description'])
tfidf.predict(1)
# Out:
# [(18, 0.3456217516488277),
#  (64, 0.25081863662401455),
#  (206, 0.23871484171563714),
#  (54, 0.22201538445055624),
#  (27, 0.21251889709074823),
#  (85, 0.17885666037507125),
#  (152, 0.17296888206507627),
#  (143, 0.15937823328266346),
#  (0, 0.15808489988972269),
#  (162, 0.14093024310173788)]

# %%
bow = BagOfWords()
bow.fit(nl_df['description'])
bow.predict(1)
# Out:
# [(18, 0.4529108136578383),
#  (152, 0.44232586846469146),
#  (27, 0.4216370213557839),
#  (64, 0.39629696195060854),
#  (85, 0.3872983346207417),
#  (162, 0.3872983346207417),
#  (155, 0.3857583749052298),
#  (103, 0.38507702310770275),
#  (54, 0.3689323936863109),
#  (125, 0.3689323936863109)]

# %% [markdown]
# #### Generate

# %%
def generate_recommendation(board_id: int, cosine_sim: ndarray=None, top_k: int=10, threshold: float=0.5) -> list:
    """
    1. 추천을 생성한다
    2. thresholding을 한다 
    3. 같은 스토어 상품을 제외한다
    4. topk를 뽑는다
        - 안되면 예외처리한다
    :params:
        id : int : product id
        cosine_sim : ndarray : cosine similarity matrix
        top_k : int : number of recommendation
        threshold : float : similarity threshold
    :return:
    """
    idx = id2idx[board_id]
    sim_scores = list(enumerate(cosine_sim[idx]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True) # score 기준으로 정렬
    sim_scores = [i for i in sim_scores if i[1] > threshold]
    sim_scores = sim_scores[1:top_k+1] 
    candidate = [(board_id, idx2id[i], score) for i, score in sim_scores] # id, score 형태로 변환 
    product_indices = [i[0] for i in sim_scores]
    # print(product_indices)
    print('Query Item:\n ', df[['title', 'purchase_url']].iloc[idx])
    print('Recommendation Items:\n', df[['title', 'purchase_url']].iloc[product_indices], '\n', '------------------------')
    return candidate

# %%
result = generate_recommendation(board_id=15, cosine_sim=tfidf.cosine_matrix, top_k=3)
# Out:
# Recommendation Items:
#          title  \
# 124  비건버터 쌀식빵
#
#                                                          purchase_url
# 124  https://smartstore.naver.com/dearmyqueen1553/products/9022144231

# %%
result = generate_recommendation(board_id=5, cosine_sim=bow.cosine_matrix, top_k=3)
# Out:
# Query Item:
#   title                                              꾸디 비건쿠키 (르뱅쿠키 수제쿠키)
# purchase_url    https://smartstore.naver.com/ggudi/products/5350602475
# Name: 4, dtype: object
# Recommendation Items:
#                            title  \
# 166       스모어쿠키 르뱅 수제 아메리칸 비건쿠키
# 30        비건쿠키 글루텐프리 쌀 수제 건강 간식
# 128  비건이레 수제 비건 쿠키 얼그레이오망아메리칸쿠키
#
#                                                              purchase_url
# 166              https://smartstore.naver.com/veganez/products/9899474228
# 30            https://smartstore.naver.com/chopcookie/products/9606521978
# 128  https://smartstore.naver.com/vegan_for_sevendays/products/5954319644
#  ------------------------

# %% [markdown]
# #### Postprocessing
# - 같은 스토어의 제품은 나오지 않게 한다
# - 품절된 상품은 나오지 않게 한다

# %%
board_id_2_store_id = {board_id:store_id for board_id, store_id in zip(df['id'], df['store_id'])}
def store_exist(board_id:int, recommended_store_id_set: set)->bool:
    store_id = board_id_2_store_id.get(board_id, None)
    return store_id in recommended_store_id_set

from collections import defaultdict
# boardid가 같은 storeid를 갖고있는지 확인
recommend_dict = defaultdict(list)
recommended_store_id_set = set()
for board_id, recommendation_board_id, score in result:
    recommended_store_id = board_id_2_store_id.get(recommendation_board_id, None)
    if len(recommend_dict[board_id]) < 3:
        if not store_exist(recommendation_board_id, recommended_store_id_set):
            recommended_store_id_set.add(recommended_store_id)
            recommend_dict[board_id].append((recommendation_board_id, score))

# %% [markdown]
# #### Metrics

# %%
from metrics.coverage import get_coverage

total_cnt = nl_df['id'].nunique()
rec_list = []
for board_id in nl_df['id']:
    result = generate_recommendation(board_id, bow.cosine_matrix, 3)
    rec_list.extend([x[1] for x in result])
rec_set = set(rec_list)
get_coverage(rec_set, total_cnt)
# Out:
# Query Item:
#   title                                      냥빵 파운드 저탄수 대체당 제로 빵 글루텐프리 건강빵 비건
# purchase_url    https://smartstore.naver.com/nyangppang/products/5907549396
# Name: 0, dtype: object
# Recommendation Items:
#                              title  \
# 135              비건 글루텐프리 베이글 [쑥]
# 42   카카오 큐브 대체당 냥빵 글루텐프리 대체당 노밀가루
# 26              비건 글루텐프리 베이글 [호박]
#
#                                                           purchase_url
# 135  https://smartstore.naver.com/dearmyqueen1553/products/10408024042
# 42         https://smartstore.naver.com/nyangppang/products/8303689276
# 26   https://smartstore.naver.com/dearmyqueen1553/products/10408016820
#  ------------------------
# Query Item:
#   title                               비건 유기농 쌀 & 기장쌀 잡곡 비스코티 5종 미앤드리 글루텐프리
# purchase_url    https://smartstore.naver.com/meandri/products/8173331858
# Name: 1, dtype: object
# Recommendation Items:
#  Empty DataFrame
# Columns: [title, purchase_url]
# Index: []
#  ------------------------
# Query Item:
#   title                                          비건이레 비건케이크 글루텐프리 떠먹는케이크 얼그레이아몬드베린느 GF
# purchase_url    https://smartstore.naver.com/vegan_for_sevendays/products/7236359151
# Name: 2, dtype: object
# Recommendation Items:
#  Empty DataFrame
# Columns: [title, purchase_url]
# Index: []
#  ------------------------
# Query Item:
#   title                          프로넛 무설탕 자일리톨 캔디 레몬 선물 사탕 금연 양치 아이간식 어린이집
# purchase_url    https://smartstore.naver.com/pronut/products/9782392925
# Name: 3, dtype: object
# Recommendation Items:
#  Empty DataFrame
# Columns: [title, purchase_url]
# Index: []
#  ------------------------
# Query Item:
#   title                                              꾸디 비건쿠키 (르뱅쿠키 수제쿠키)
# purchase_url    https://smartstore.naver.com/ggudi/products/5350602475
# Name: 4, dtype: object
# Recommendation Items:
#                            title  \
# 166       스모어쿠키 르뱅 수제 아메리칸 비건쿠키
# 30        비건쿠키 글루텐프리 쌀 수제 건강 간식
# 128  비건이레 수제 비건 쿠키 얼그레이오망아메리칸쿠키
#
#                                                              purchase_url
# 166              https://smartstore.naver.com/veganez/products/9899474228
# 30            https://smartstore.naver.com/chopcookie/products/9606521978
# 128  https://smartstore.naver.com/vegan_for_sevendays/products/5954319644
#  ------------------------
# Query Item:
#   title                                     [쌀낭시에 5종x2개입] 비건빵 글루텐프리 쌀빵 휘낭시에 건강간식
# purchase_url    https://smartstore.naver.com/thebreadblue/products/10524498266
# Name: 5, dtype: object
# Recommendation Items:
#                              title  \
# 28   현미 카스테라 비건빵 글루텐프리 쌀빵 디저트 건강빵
# 138       소소한 소금빵 비건빵 100% 건강빵 간식
#
#                                                       purchase_url
# 28   https://smartstore.naver.com/thebreadblue/products/5314431844
# 138  https://smartstore.naver.com/thebreadblue/products/7048770140
#  ------------------------
# Query Item:
#   title                          꾸디 이달의 비건디저트 (비건쿠키 비건빵 베이커리 웨딩임페리얼 무화과)
# purchase_url    https://smartstore.naver.com/ggudi/products/6552077533
# Name: 6, dtype: object
# Recommendation Items:
#                           title  \
# 29  무설탕 비건베이커리 디저트 빵 간식 흑임자 쿠키
#
#                                                 purchase_url
# 29  https://smartstore.naver.com/veganez/products/9959060143
#  ------------------------
# Query Item:
#   title                                       [통밀발효종빵 3개 세트] 속이 편안한 통밀발효종 건강 비건빵
# purchase_url    https://smartstore.naver.com/thebreadblue/products/10058561759
# Name: 7, dtype: object
# Recommendation Items:
#                                            title  \
# 8    [발효종 순수 통밀빵 2개입 1세트] 저당빵 비건 건강 식사대용 더브레드블루
# 75       [달콤 통밀 크럼블] 더브레드블루 비건빵 건강간식 통밀 건강 식사대용
# 165    [통밀100] 비건빵 100% 통밀빵 샌드위치 파니니 식사대용 건강 간식
#
#                                                        purchase_url
# 8    https://smartstore.naver.com/thebreadblue/products/10462893106
# 75   https://smartstore.naver.com/thebreadblue/products/10612945426
# 165  https://smartstore.naver.com/thebreadblue/products/10633414319
#  ------------------------
# Query Item:
#   title                               [발효종 순수 통밀빵 2개입 1세트] 저당빵 비건 건강 식사대용 더브레드블루
# purchase_url    https://smartstore.naver.com/thebreadblue/products/10462893106
# Name: 8, dtype: object
# Recommendation Items:
#                                         title  \
# 75    [달콤 통밀 크럼블] 더브레드블루 비건빵 건강간식 통밀 건강 식사대용
# 97   [밤식빵] 식사대용 비건 건강 통밤 소화잘되는 더브레드블루 (280g)
# 187      [감자 치아바타] 저당빵, 비건빵, 건강빵 식사대용 더브레드블루
#
#                                                        purchase_url
# 75   https://smartstore.naver.com/thebreadblue/products/10612945426
# 97   https://smartstore.naver.com/thebreadblue/products/10573316986
# 187  https://smartstore.naver.com/thebreadblue/products/10217185928
#  ------------------------
# Query Item:
#   title                     굿다운 1/9 저칼로리 저당 치아딸기잼, 서울어워드수상 당뇨와건강몰입점 스테비아잼 무설탕잼
# purchase_url    https://smartstore.naver.com/grimmsbread/products/7318233551
# Name: 9, dtype: object
# Recommendation Items:
#                                                    title  \
# 182                                      굿다운 저당 초코잼, 1병
# 68   (1병+1병) 그림의빵 굿다운 1/9 저칼로리 저당 치아딸기잼, 서울어워드수상 당뇨와건강몰
# 24       굿다운 1/9저칼로리 저당 딸기잼 1kg 리필팩, 당뇨키토몰입점 스테비아잼 굿다운잼
#
#                                                       purchase_url
# 182  https://smartstore.naver.com/grimmsbread/products/10394185921
# 68    https://smartstore.naver.com/grimmsbread/products/8590293765
# 24    https://smartstore.naver.com/grimmsbread/products/9418851993
#  ------------------------
# Query Item:
#   title                                     [모닐이네하우스] 글루텐프리 100% 쌀 소금빵 5개 세트구성
# purchase_url    https://smartstore.naver.com/monil2house/products/9108823733
# Name: 10, dtype: object
# Recommendation Items:
#                                          title  \
# 189         [모닐이네하우스] Best 100% 쌀 소금빵 (글루텐프리)
# 152  [모닐이네하우스] 🌾 100% 글루텐프리 쌀로 만든 베이글 (비건/GF)
#
#                                                      purchase_url
# 189  https://smartstore.naver.com/monil2house/products/8907264126
# 152  https://smartstore.naver.com/monil2house/products/8866615221
#  ------------------------
# Query Item:
#   title                                                  콩볼 쿠키볼 / 로키 오트밀 쿠키
# purchase_url    https://smartstore.naver.com/rawsome/products/10774827105
# Name: 11, dtype: object
# Recommendation Items:
#  Empty DataFrame
# Columns: [title, purchase_url]
# Index: []
#  ------------------------
# Query Item:
#   title                                       키토빵앗간 고메버터 파운드 (저당 글루텐프리 저탄수빵)
# purchase_url    https://smartstore.naver.com/ketobbang/products/5774916041
# Name: 12, dtype: object
# Recommendation Items:
#                                                 title  \
# 47                    비건이레 비건빵 글루텐프리 홀파운드케이크 쑥무화과파운드
# 163  [포포브레드] 홀 파운드 3종 / 크리스마스 글루텐프리 케이크 노밀가루 비건 베이커리
# 180    [포포브레드] 파운드 3종 / 쌀 디저트 글루텐프리 케이크 노밀가루 비건 베이커리
#
#                                                              purchase_url
# 47   https://smartstore.naver.com/vegan_for_sevendays/products/5493037223
# 163         https://smartstore.naver.com/forfourbread/products/6001277363
# 180         https://smartstore.naver.com/forfourbread/products/5268911320
#  ------------------------
# Query Item:
#   title                                   저당 단백 모닝빵 5개입 무설탕 무밀가루 저당질 프로틴 단백질빵
# purchase_url    https://smartstore.naver.com/ketopantry/products/8754612023
# Name: 13, dtype: object
# Recommendation Items:
#  Empty DataFrame
# Columns: [title, purchase_url]
# Index: []
#  ------------------------
# Query Item:
#   title                                                               수제 비건버터 쌀소금빵
# purchase_url    https://smartstore.naver.com/dearmyqueen1553/products/8094049097
# Name: 14, dtype: object
# Recommendation Items:
#                    title  \
# 124            비건버터 쌀식빵
# 56   비건 쌀 마들렌 - 아마레또 커피
# 135    비건 글루텐프리 베이글 [쑥]
#
#                                                           purchase_url
# 124   https://smartstore.naver.com/dearmyqueen1553/products/9022144231
# 56   https://smartstore.naver.com/dearmyqueen1553/products/10663549774
# 135  https://smartstore.naver.com/dearmyqueen1553/products/10408024042
#  ------------------------
# Query Item:
#   title                                      [빵어니스타] 비건 쌀 빠삭쿠키 (당일 미입금 시 주문 취소)
# purchase_url    https://smartstore.naver.com/shophonesta/products/10524616367
# Name: 15, dtype: object
# Recommendation Items:
#                                            title  \
# 122  [빵어니스타] 비건 라미쿠키 개별 구매 페이지 (당일 미입금 시 주문 취소)
#
#                                                      purchase_url
# 122  https://smartstore.naver.com/shophonesta/products/6130615730
#  ------------------------
# Query Item:
#   title                                        카라멜 피칸 견과 쿠키 퇴사 답례품 선물 비건쿠키
# purchase_url    https://smartstore.naver.com/veganez/products/9899487132
# Name: 16, dtype: object
# Recommendation Items:
#                              title  \
# 4             꾸디 비건쿠키 (르뱅쿠키 수제쿠키)
# 133                 비건 아메리칸 쿠키 2종
# 143  땅콩이 피칸 볼 쿠키 비건쿠키 글루텐프리 저당 간식
#
#                                                          purchase_url
# 4              https://smartstore.naver.com/ggudi/products/5350602475
# 133  https://smartstore.naver.com/dearmyqueen1553/products/8723454443
# 143          https://smartstore.naver.com/veganez/products/9899459424
#  ------------------------
# Query Item:
#   title                                          레몬 얼그레이 수제쿠키 쌀 글루텐프리 비건쿠키
# purchase_url    https://smartstore.naver.com/veganez/products/9899464494
# Name: 17, dtype: object
# Recommendation Items:
#                            title  \
# 85   얼그레이 초코볼 볼쿠키 비건쿠키 저당 글루텐프리
# 195   초콜렛칩 쿠키 노밀가루 쌀 글루텐프리 비건쿠키
# 4           꾸디 비건쿠키 (르뱅쿠키 수제쿠키)
#
#                                                  purchase_url
# 85   https://smartstore.naver.com/veganez/products/9899451546
# 195  https://smartstore.naver.com/veganez/products/9899550033
# 4      https://smartstore.naver.com/ggudi/products/5350602475
#  ------------------------
# Query Item:
#   title                                   비건 유기농 쌀 제로슈가 고구마브라우니 미앤드리 글루텐프리
# purchase_url    https://smartstore.naver.com/meandri/products/8015455745
# Name: 18, dtype: object
# Recommendation Items:
#  Empty DataFrame
# Columns: [title, purchase_url]
# Index: []
#  ------------------------
# Query Item:
#   title                        [구운 통밀 고로케 3개입 세트] 야채 고로케, 비건 간식, 식사대용, 구운 통밀 고로케
# purchase_url    https://smartstore.naver.com/thebreadblue/products/10463029522
# Name: 19, dtype: object
# Recommendation Items:
#                                        title  \
# 121  [구운 통밀 고로케 6개입 세트] 야채 고로케, 비건 간식, 식사대용
#
#                                                        purchase_url
# 121  https://smartstore.naver.com/thebreadblue/products/10472067235
#  ------------------------
# Query Item:
#   title                                                 비건이레 비건 티케이크 비건빵 글루텐프리 단호박티케이크
# purchase_url    https://smartstore.naver.com/vegan_for_sevendays/products/5604418319
# Name: 20, dtype: object
# Recommendation Items:
#                             title  \
# 34  비건케이크 비건 티라미수 떠먹는 쌀케이크 글루텐프리
# 66                 메종드비건 홀파운드케이크
#
#                                                         purchase_url
# 34        https://smartstore.naver.com/vegandaum/products/6144628768
# 66  https://smartstore.naver.com/maison_de_vegan/products/4788638756
#  ------------------------
# Query Item:
#   title                                틴베이크 플틴쿠키 저당 고단백 프로틴 단백질 월넛오리지널 쿠키 빵
# purchase_url    https://smartstore.naver.com/teinbake/products/5754369653
# Name: 21, dtype: object
# Recommendation Items:
#                          title  \
# 4         꾸디 비건쿠키 (르뱅쿠키 수제쿠키)
# 141  키토빵앗간 쿠키 (저당 글루텐프리 저탄수빵)
# 30      비건쿠키 글루텐프리 쌀 수제 건강 간식
#
#                                                     purchase_url
# 4         https://smartstore.naver.com/ggudi/products/5350602475
# 141   https://smartstore.naver.com/ketobbang/products/6112318422
# 30   https://smartstore.naver.com/chopcookie/products/9606521978
#  ------------------------
# Query Item:
#   title                                      글루텐프리 다이어트빵 쌀디저트 쌀마들렌 2개세트 할인 비건
# purchase_url    https://smartstore.naver.com/earth-born/products/8151293245
# Name: 22, dtype: object
# Recommendation Items:
#                                                  title  \
# 151  글루텐프리 다이어트빵 쌀디저트 찹쌀휘낭시에 2개 세트 비건 구움과자 선물 바닐라 카카오
#
#                                                     purchase_url
# 151  https://smartstore.naver.com/earth-born/products/7862724112
#  ------------------------
# Query Item:
#   title                       [모닐이네하우스] 특허받은 레시피로 만든 무설탕, 노밀가루, 노생크림 갸또쇼콜라 시리즈
# purchase_url    https://smartstore.naver.com/monil2house/products/8606659063
# Name: 23, dtype: object
# Recommendation Items:
#                                                  title  \
# 62     [모닐이네하우스] 특허받은 레시피, 콩으로 만든 무설탕 노생크림 키쇼(키토 쇼콜라)
# 94   [모닐이네하우스] 특허 레시피로 만든 무설탕, 글루텐프리 2단 초콜릿 케이크 DIY키트
# 202         [모닐이네하우스] 무설탕 3단 초콜릿 케이크 DIY키트 (연말파티, 행사)
#
#                                                      purchase_url
# 62   https://smartstore.naver.com/monil2house/products/8606334927
# 94   https://smartstore.naver.com/monil2house/products/8606793020
# 202  https://smartstore.naver.com/monil2house/products/9324661358
#  ------------------------
# Query Item:
#   title                         굿다운 1/9저칼로리 저당 딸기잼 1kg 리필팩, 당뇨키토몰입점 스테비아잼 굿다운잼
# purchase_url    https://smartstore.naver.com/grimmsbread/products/9418851993
# Name: 24, dtype: object
# Recommendation Items:
#                                                   title  \
# 9   굿다운 1/9 저칼로리 저당 치아딸기잼, 서울어워드수상 당뇨와건강몰입점 스테비아잼 무설탕잼
# 68  (1병+1병) 그림의빵 굿다운 1/9 저칼로리 저당 치아딸기잼, 서울어워드수상 당뇨와건강몰
#
#                                                     purchase_url
# 9   https://smartstore.naver.com/grimmsbread/products/7318233551
# 68  https://smartstore.naver.com/grimmsbread/products/8590293765
#  ------------------------
# Query Item:
#   title                          그림의빵 완벽저당 전제품 맛보기 10개 세트(1/9딸기잼 포함), 당뇨와건강몰입점
# purchase_url    https://smartstore.naver.com/grimmsbread/products/8158079418
# Name: 25, dtype: object
# Recommendation Items:
#                                                    title  \
# 68   (1병+1병) 그림의빵 굿다운 1/9 저칼로리 저당 치아딸기잼, 서울어워드수상 당뇨와건강몰
# 168  그림의빵 저당빵 베스트셀러 달콤세트 10개(크림빵3종+휘낭시에2종), 각2개씩 당뇨와건강몰
#
#                                                      purchase_url
# 68   https://smartstore.naver.com/grimmsbread/products/8590293765
# 168  https://smartstore.naver.com/grimmsbread/products/8158097442
#  ------------------------
# Query Item:
#   title                                                           비건 글루텐프리 베이글 [호박]
# purchase_url    https://smartstore.naver.com/dearmyqueen1553/products/10408016820
# Name: 26, dtype: object
# Recommendation Items:
#                                          title  \
# 135                          비건 글루텐프리 베이글 [쑥]
# 35                         비건 글루텐프리 베이글 [기본맛]
# 152  [모닐이네하우스] 🌾 100% 글루텐프리 쌀로 만든 베이글 (비건/GF)
#
#                                                           purchase_url
# 135  https://smartstore.naver.com/dearmyqueen1553/products/10408024042
# 35    https://smartstore.naver.com/dearmyqueen1553/products/8197094252
# 152       https://smartstore.naver.com/monil2house/products/8866615221
#  ------------------------
# Query Item:
#   title                                       비건 유기농 쌀 노오일 휘낭시에 드낭시에 글루텐프리
# purchase_url    https://smartstore.naver.com/meandri/products/8726000877
# Name: 27, dtype: object
# Recommendation Items:
#  Empty DataFrame
# Columns: [title, purchase_url]
# Index: []
#  ------------------------
# Query Item:
#   title                                            현미 카스테라 비건빵 글루텐프리 쌀빵 디저트 건강빵
# purchase_url    https://smartstore.naver.com/thebreadblue/products/5314431844
# Name: 28, dtype: object
# Recommendation Items:
#                                            title  \
# 5          [쌀낭시에 5종x2개입] 비건빵 글루텐프리 쌀빵 휘낭시에 건강간식
# 36   [동호가 만든 현미빵] 더브레드블루 비건빵 쌀빵 건강간식 저당 건강 식사대용
# 135                            비건 글루텐프리 베이글 [쑥]
#
#                                                           purchase_url
# 5       https://smartstore.naver.com/thebreadblue/products/10524498266
# 36      https://smartstore.naver.com/thebreadblue/products/10613235094
# 135  https://smartstore.naver.com/dearmyqueen1553/products/10408024042
#  ------------------------
# Query Item:
#   title                                         무설탕 비건베이커리 디저트 빵 간식 흑임자 쿠키
# purchase_url    https://smartstore.naver.com/veganez/products/9959060143
# Name: 29, dtype: object
# Recommendation Items:
#                                         title  \
# 6    꾸디 이달의 비건디저트 (비건쿠키 비건빵 베이커리 웨딩임페리얼 무화과)
# 150                 저당간식 비건베이커리 글루텐프리 아몬드 쿠키
# 183         [비건 쿠키] 건강 간식, 영양 간식, 채식, 식물성 쿠키
#
#                                                       purchase_url
# 6           https://smartstore.naver.com/ggudi/products/6552077533
# 150      https://smartstore.naver.com/veganez/products/10088851664
# 183  https://smartstore.naver.com/thebreadblue/products/9686069150
#  ------------------------
# Query Item:
#   title                                                 비건쿠키 글루텐프리 쌀 수제 건강 간식
# purchase_url    https://smartstore.naver.com/chopcookie/products/9606521978
# Name: 30, dtype: object
# Recommendation Items:
#                                          title  \
# 141                  키토빵앗간 쿠키 (저당 글루텐프리 저탄수빵)
# 4                         꾸디 비건쿠키 (르뱅쿠키 수제쿠키)
# 171  [포포브레드] 쿠키 4종 / 쌀 디저트 글루텐프리 노밀가루 비건 베이커리
#
#                                                       purchase_url
# 141     https://smartstore.naver.com/ketobbang/products/6112318422
# 4           https://smartstore.naver.com/ggudi/products/5350602475
# 171  https://smartstore.naver.com/forfourbread/products/5176015845
#  ------------------------
# Query Item:
#   title                                      [모닐이네하우스] 수제 쌀 르뱅 쿠키 시리즈 9종 글루텐프리
# purchase_url    https://smartstore.naver.com/monil2house/products/8623551874
# Name: 31, dtype: object
# Recommendation Items:
#                                  title  \
# 191  글루텐프리 수제쿠키 저당 디저트맛집 마카다미아 쿠키-2개입
#
#                                                        purchase_url
# 191  https://smartstore.naver.com/humming_pound/products/5469178935
#  ------------------------
# Query Item:
#   title                          레몬 키토 머핀 저탄고지 냥빵 저탄수 빵 저당안심 식사대용 빵 무설탕 비건 키토
# purchase_url    https://smartstore.naver.com/nyangppang/products/8303655332
# Name: 32, dtype: object
# Recommendation Items:
#  Empty DataFrame
# Columns: [title, purchase_url]
# Index: []
#  ------------------------
# Query Item:
#   title                                                           비건 쌀 마들렌 - 초코칩 초코
# purchase_url    https://smartstore.naver.com/dearmyqueen1553/products/10663546111
# Name: 33, dtype: object
# Recommendation Items:
#                                            title  \
# 122  [빵어니스타] 비건 라미쿠키 개별 구매 페이지 (당일 미입금 시 주문 취소)
# 56                           비건 쌀 마들렌 - 아마레또 커피
# 61                               미니 발로나 초코 브라우니
#
#                                                           purchase_url
# 122       https://smartstore.naver.com/shophonesta/products/6130615730
# 56   https://smartstore.naver.com/dearmyqueen1553/products/10663549774
# 61    https://smartstore.naver.com/dearmyqueen1553/products/9975947397
#  ------------------------
# Query Item:
#   title                                         비건케이크 비건 티라미수 떠먹는 쌀케이크 글루텐프리
# purchase_url    https://smartstore.naver.com/vegandaum/products/6144628768
# Name: 34, dtype: object
# Recommendation Items:
#                               title  \
# 20  비건이레 비건 티케이크 비건빵 글루텐프리 단호박티케이크
# 66                   메종드비건 홀파운드케이크
#
#                                                             purchase_url
# 20  https://smartstore.naver.com/vegan_for_sevendays/products/5604418319
# 66      https://smartstore.naver.com/maison_de_vegan/products/4788638756
#  ------------------------
# Query Item:
#   title                                                         비건 글루텐프리 베이글 [기본맛]
# purchase_url    https://smartstore.naver.com/dearmyqueen1553/products/8197094252
# Name: 35, dtype: object
# Recommendation Items:
#                                          title  \
# 135                          비건 글루텐프리 베이글 [쑥]
# 26                          비건 글루텐프리 베이글 [호박]
# 152  [모닐이네하우스] 🌾 100% 글루텐프리 쌀로 만든 베이글 (비건/GF)
#
#                                                           purchase_url
# 135  https://smartstore.naver.com/dearmyqueen1553/products/10408024042
# 26   https://smartstore.naver.com/dearmyqueen1553/products/10408016820
# 152       https://smartstore.naver.com/monil2house/products/8866615221
#  ------------------------
# Query Item:
#   title                               [동호가 만든 현미빵] 더브레드블루 비건빵 쌀빵 건강간식 저당 건강 식사대용
# purchase_url    https://smartstore.naver.com/thebreadblue/products/10613235094
# Name: 36, dtype: object
# Recommendation Items:
#                                      title  \
# 76   [프랑스 바게트] 더브레드블루 비건빵 건강간식 저당 건강 식사대용
# 114   [호두 깜빠뉴] 더브레드블루 비건빵 건강간식 저당 건강 식사대용
# 127    [호밀100] 더브레드블루 비건빵 건강간식 저당 건강 식사대용
#
#                                                        purchase_url
# 76   https://smartstore.naver.com/thebreadblue/products/10638101379
# 114  https://smartstore.naver.com/thebreadblue/products/10638548817
# 127  https://smartstore.naver.com/thebreadblue/products/10638521377
#  ------------------------
# Query Item:
#   title                               [더브레드블루 저당 통밀식빵] 당1g 다이어트 샌드위치 식단 노계란 비건식빵
# purchase_url    https://smartstore.naver.com/thebreadblue/products/10543930328
# Name: 37, dtype: object
# Recommendation Items:
#                                      title  \
# 116  토스트 다이어트 비건 쌀 구름식빵 샌드위치 식사대용 발효빵 미니빵
#
#                                                          purchase_url
# 116  https://smartstore.naver.com/dearmyqueen1553/products/8127101482
#  ------------------------
# Query Item:
#   title                                   [모닐이네하우스] 치즈 여왕 노밀가루 바스크 치즈케이크 글루텐프리
# purchase_url    https://smartstore.naver.com/monil2house/products/8606876163
# Name: 38, dtype: object
# Recommendation Items:
#  Empty DataFrame
# Columns: [title, purchase_url]
# Index: []
#  ------------------------
# Query Item:
#   title                           [모닐이네하우스] No밀가루, 글루텐프리 수제 큐브 쌀 파운드 (2개씩) 시리즈
# purchase_url    https://smartstore.naver.com/monil2house/products/8954469522
# Name: 39, dtype: object
# Recommendation Items:
#  Empty DataFrame
# Columns: [title, purchase_url]
# Index: []
#  ------------------------
# Query Item:
#   title                                                         우주 크림빵(초코, 밀크)
# purchase_url    https://smartstore.naver.com/dduddustore/products/7641130759
# Name: 40, dtype: object
# Recommendation Items:
#                      title  \
# 111  우주 크림빵[밀크, 초코][10개입]
#
#                                                       purchase_url
# 111  https://smartstore.naver.com/dduddustore/products/10499656249
#  ------------------------
# Query Item:
#   title                     저당모닝빵4팩+저당딸기잼 1kg 리필팩 세트구성, 저칼로리잼, 100%곡물단백질, 당뇨키토
# purchase_url    https://smartstore.naver.com/grimmsbread/products/8248603713
# Name: 41, dtype: object
# Recommendation Items:
#                                                    title  \
# 193  (3팩+3팩) 그림의빵 모닝빵 총 6팩, 저당식단용빵 100%곡물단백질 당뇨와건강몰입점 노
# 197  그림의빵 코코모닝빵 3팩, 저당식단용빵 100%곡물단백질 당뇨와건강몰입점 노밀가루 저당 고
#
#                                                      purchase_url
# 193  https://smartstore.naver.com/grimmsbread/products/9718870989
# 197  https://smartstore.naver.com/grimmsbread/products/7318221629
#  ------------------------
# Query Item:
#   title                                          카카오 큐브 대체당 냥빵 글루텐프리 대체당 노밀가루
# purchase_url    https://smartstore.naver.com/nyangppang/products/8303689276
# Name: 42, dtype: object
# Recommendation Items:
#                                title  \
# 0  냥빵 파운드 저탄수 대체당 제로 빵 글루텐프리 건강빵 비건
#
#                                                   purchase_url
# 0  https://smartstore.naver.com/nyangppang/products/5907549396
#  ------------------------
# Query Item:
#   title                             프로틴빵 노밀가루 글루텐프리 식단관리 단백질빵 당조절 식사빵 카스테라
# purchase_url    https://smartstore.naver.com/6-bbang/products/5242705272
# Name: 43, dtype: object
# Recommendation Items:
#  Empty DataFrame
# Columns: [title, purchase_url]
# Index: []
#  ------------------------
# Query Item:
#   title                                             클래식 소보로빵 비건빵 100% 건강빵 영양 간식
# purchase_url    https://smartstore.naver.com/thebreadblue/products/8605330694
# Name: 44, dtype: object
# Recommendation Items:
#                                           title  \
# 91           클래식 단팥빵 비건빵 100% 건강빵 영양 간식 더브레드블루
# 46   [클래식 단팥빵 5개 세트] 비건빵 100% 건강빵 영양 간식 더브레드블루
# 138                    소소한 소금빵 비건빵 100% 건강빵 간식
#
#                                                        purchase_url
# 91    https://smartstore.naver.com/thebreadblue/products/8605319670
# 46   https://smartstore.naver.com/thebreadblue/products/10437959557
# 138   https://smartstore.naver.com/thebreadblue/products/7048770140
#  ------------------------
# Query Item:
#   title                                     매주 목요일 2pm 오픈 비건쿠키 노오일 글루텐프리 두부크림치즈
# purchase_url    https://smartstore.naver.com/splashbakery/products/8313644614
# Name: 45, dtype: object
# Recommendation Items:
#                          title  \
# 141  키토빵앗간 쿠키 (저당 글루텐프리 저탄수빵)
# 30      비건쿠키 글루텐프리 쌀 수제 건강 간식
# 4         꾸디 비건쿠키 (르뱅쿠키 수제쿠키)
#
#                                                     purchase_url
# 141   https://smartstore.naver.com/ketobbang/products/6112318422
# 30   https://smartstore.naver.com/chopcookie/products/9606521978
# 4         https://smartstore.naver.com/ggudi/products/5350602475
#  ------------------------
# Query Item:
#   title                                [클래식 단팥빵 5개 세트] 비건빵 100% 건강빵 영양 간식 더브레드블루
# purchase_url    https://smartstore.naver.com/thebreadblue/products/10437959557
# Name: 46, dtype: object
# Recommendation Items:
#                                         title  \
# 91         클래식 단팥빵 비건빵 100% 건강빵 영양 간식 더브레드블루
# 44               클래식 소보로빵 비건빵 100% 건강빵 영양 간식
# 48  [더브레드블루 간식빵 6종 맛보기 세트] 비건빵 100% 건강빵 생일선물
#
#                                                       purchase_url
# 91   https://smartstore.naver.com/thebreadblue/products/8605319670
# 44   https://smartstore.naver.com/thebreadblue/products/8605330694
# 48  https://smartstore.naver.com/thebreadblue/products/10498310126
#  ------------------------
# Query Item:
#   title                                                 비건이레 비건빵 글루텐프리 홀파운드케이크 쑥무화과파운드
# purchase_url    https://smartstore.naver.com/vegan_for_sevendays/products/5493037223
# Name: 47, dtype: object
# Recommendation Items:
#                                                 title  \
# 163  [포포브레드] 홀 파운드 3종 / 크리스마스 글루텐프리 케이크 노밀가루 비건 베이커리
# 180    [포포브레드] 파운드 3종 / 쌀 디저트 글루텐프리 케이크 노밀가루 비건 베이커리
# 136              틴베이크 프로틴 단백질 플틴 바나나 파운드 케이크 식사 식단 빵
#
#                                                       purchase_url
# 163  https://smartstore.naver.com/forfourbread/products/6001277363
# 180  https://smartstore.naver.com/forfourbread/products/5268911320
# 136      https://smartstore.naver.com/teinbake/products/8698425868
#  ------------------------
# Query Item:
#   title                                 [더브레드블루 간식빵 6종 맛보기 세트] 비건빵 100% 건강빵 생일선물
# purchase_url    https://smartstore.naver.com/thebreadblue/products/10498310126
# Name: 48, dtype: object
# Recommendation Items:
#                                           title  \
# 46   [클래식 단팥빵 5개 세트] 비건빵 100% 건강빵 영양 간식 더브레드블루
# 91           클래식 단팥빵 비건빵 100% 건강빵 영양 간식 더브레드블루
# 113           [소소한 소금빵 10개 세트] 비건빵 100% 건강빵 간식
#
#                                                        purchase_url
# 46   https://smartstore.naver.com/thebreadblue/products/10437959557
# 91    https://smartstore.naver.com/thebreadblue/products/8605319670
# 113  https://smartstore.naver.com/thebreadblue/products/10471607904
#  ------------------------
# Query Item:
#   title                                 틴베이크 플틴스콘 수제 고단백 프로틴 통밀빵 단백질 플레인 스콘
# purchase_url    https://smartstore.naver.com/teinbake/products/6206497546
# Name: 49, dtype: object
# Recommendation Items:
#                           title  \
# 126         비건 스콘 비건빵 팥이랑밤이레스콘
# 57                     메종드비건스콘
# 84   프로틴스콘 노밀가루 노설탕 식단조절 간식 스콘
#
#                                                              purchase_url
# 126  https://smartstore.naver.com/vegan_for_sevendays/products/5487644794
# 57       https://smartstore.naver.com/maison_de_vegan/products/4780918604
# 84               https://smartstore.naver.com/6-bbang/products/5374954271
#  ------------------------
# Query Item:
#   title                                                              두부 쌀 베이글
# purchase_url    https://smartstore.naver.com/earth-born/products/9988173082
# Name: 50, dtype: object
# Recommendation Items:
#                                title  \
# 153  틴베이크 통밀 단백질 프로틴 베이글 식사 식단 아침 빵
#
#                                                   purchase_url
# 153  https://smartstore.naver.com/teinbake/products/9809774432
#  ------------------------
# Query Item:
#   title                                    비건 이지 뉴초콜렛칩 쿠키 노밀가루 쌀 글루텐프리 비건쿠키
# purchase_url    https://smartstore.naver.com/veganez/products/10464483924
# Name: 51, dtype: object
# Recommendation Items:
#                            title  \
# 195   초콜렛칩 쿠키 노밀가루 쌀 글루텐프리 비건쿠키
# 17    레몬 얼그레이 수제쿠키 쌀 글루텐프리 비건쿠키
# 85   얼그레이 초코볼 볼쿠키 비건쿠키 저당 글루텐프리
#
#                                                  purchase_url
# 195  https://smartstore.naver.com/veganez/products/9899550033
# 17   https://smartstore.naver.com/veganez/products/9899464494
# 85   https://smartstore.naver.com/veganez/products/9899451546
#  ------------------------
# Query Item:
#   title                                   당류 0g 저당 마들렌 무설탕 무밀가루 고식이섬유 식단 간식 디저
# purchase_url    https://smartstore.naver.com/ketopantry/products/10282880886
# Name: 52, dtype: object
# Recommendation Items:
#                                           title  \
# 209  [포포브레드] 마들렌 4종 / 쌀 디저트 글루텐프리 노밀가루 비건 베이커리
#
#                                                       purchase_url
# 209  https://smartstore.naver.com/forfourbread/products/5268905112
#  ------------------------
# Query Item:
#   title                                     [모닐이네하우스] 수제 쌀 스콘 시리즈 글루텐프리, NO 에그
# purchase_url    https://smartstore.naver.com/monil2house/products/8644062785
# Name: 53, dtype: object
# Recommendation Items:
#  Empty DataFrame
# Columns: [title, purchase_url]
# Index: []
#  ------------------------
# Query Item:
#   title                          [포포브레드] 비건 비스코티 초코 아몬드 / 쌀 디저트 글루텐프리 노밀가루 베이커리
# purchase_url    https://smartstore.naver.com/forfourbread/products/9780373383
# Name: 54, dtype: object
# Recommendation Items:
#                                            title  \
# 100    [포포브레드] 스콘 3종 / 쌀 디저트 글루텐프리 노밀가루 비건 베이커리
# 130  [포포브레드] 조각 호두파이 / 쌀 디저트 글루텐프리 노밀가루 비건 베이커리
#
#                                                       purchase_url
# 100  https://smartstore.naver.com/forfourbread/products/5268965054
# 130  https://smartstore.naver.com/forfourbread/products/8127086196
#  ------------------------
# Query Item:
#   title                                  비건 유기농 쌀 프로틴 쿠콘 4종 (쿠키 + 스콘) 글루텐프리
# purchase_url    https://smartstore.naver.com/meandri/products/10054409375
# Name: 55, dtype: object
# Recommendation Items:
#  Empty DataFrame
# Columns: [title, purchase_url]
# Index: []
#  ------------------------
# Query Item:
#   title                                                          비건 쌀 마들렌 - 아마레또 커피
# purchase_url    https://smartstore.naver.com/dearmyqueen1553/products/10663549774
# Name: 56, dtype: object
# Recommendation Items:
#                     title  \
# 190  비건 쌀 마들렌 - 콩고물 범벅 쑥
# 33     비건 쌀 마들렌 - 초코칩 초코
# 124             비건버터 쌀식빵
#
#                                                           purchase_url
# 190  https://smartstore.naver.com/dearmyqueen1553/products/10663557479
# 33   https://smartstore.naver.com/dearmyqueen1553/products/10663546111
# 124   https://smartstore.naver.com/dearmyqueen1553/products/9022144231
#  ------------------------
# Query Item:
#   title                                                                    메종드비건스콘
# purchase_url    https://smartstore.naver.com/maison_de_vegan/products/4780918604
# Name: 57, dtype: object
# Recommendation Items:
#                                          title  \
# 126                        비건 스콘 비건빵 팥이랑밤이레스콘
# 49        틴베이크 플틴스콘 수제 고단백 프로틴 통밀빵 단백질 플레인 스콘
# 100  [포포브레드] 스콘 3종 / 쌀 디저트 글루텐프리 노밀가루 비건 베이커리
#
#                                                              purchase_url
# 126  https://smartstore.naver.com/vegan_for_sevendays/products/5487644794
# 49              https://smartstore.naver.com/teinbake/products/6206497546
# 100         https://smartstore.naver.com/forfourbread/products/5268965054
#  ------------------------
# Query Item:
#   title                                     로투스 비스코프 비건케이크 더브레드블루 (No 계란 우유 버터)
# purchase_url    https://smartstore.naver.com/thebreadblue/products/8215949572
# Name: 58, dtype: object
# Recommendation Items:
#                                                  title  \
# 83     [더브레드블루 벨기에 초콜릿 비건케이크 1호] 생일 케이크 디저트(No우유계란버터)
# 107  [더브레드블루 생크림 비건케이크 1호] 순식물성 생일 케이크 디저트(No 우유계란버터)
# 124                                          비건버터 쌀식빵
#
#                                                          purchase_url
# 83     https://smartstore.naver.com/thebreadblue/products/10707527718
# 107    https://smartstore.naver.com/thebreadblue/products/10707546419
# 124  https://smartstore.naver.com/dearmyqueen1553/products/9022144231
#  ------------------------
# Query Item:
#   title                           저당 건강 간식 시나몬두 아몬드 호두 하루 견과류 쿠키 글루텐프리 디저트
# purchase_url    https://smartstore.naver.com/veganez/products/9911908862
# Name: 59, dtype: object
# Recommendation Items:
#                              title  \
# 150      저당간식 비건베이커리 글루텐프리 아몬드 쿠키
# 143  땅콩이 피칸 볼 쿠키 비건쿠키 글루텐프리 저당 간식
# 139        저당 비건 글루텐프리 간식 피넛버터 쿠키
#
#                                                   purchase_url
# 150  https://smartstore.naver.com/veganez/products/10088851664
# 143   https://smartstore.naver.com/veganez/products/9899459424
# 139   https://smartstore.naver.com/veganez/products/9954247586
#  ------------------------
# Query Item:
#   title                             [포포브레드] 애플베리 크럼블 / 쌀 디저트 글루텐프리 노밀가루 비건 베이커리
# purchase_url    https://smartstore.naver.com/forfourbread/products/5416047304
# Name: 60, dtype: object
# Recommendation Items:
#  Empty DataFrame
# Columns: [title, purchase_url]
# Index: []
#  ------------------------
# Query Item:
#   title                                                             미니 발로나 초코 브라우니
# purchase_url    https://smartstore.naver.com/dearmyqueen1553/products/9975947397
# Name: 61, dtype: object
# Recommendation Items:
#                  title  \
# 33  비건 쌀 마들렌 - 초코칩 초코
#
#                                                          purchase_url
# 33  https://smartstore.naver.com/dearmyqueen1553/products/10663546111
#  ------------------------
# Query Item:
#   title                         [모닐이네하우스] 특허받은 레시피, 콩으로 만든 무설탕 노생크림 키쇼(키토 쇼콜라)
# purchase_url    https://smartstore.naver.com/monil2house/products/8606334927
# Name: 62, dtype: object
# Recommendation Items:
#                                                  title  \
# 94   [모닐이네하우스] 특허 레시피로 만든 무설탕, 글루텐프리 2단 초콜릿 케이크 DIY키트
# 23   [모닐이네하우스] 특허받은 레시피로 만든 무설탕, 노밀가루, 노생크림 갸또쇼콜라 시리즈
# 147     [모닐이네하우스] 쌀로 만든 츄러스 (글루텐프리, 설탕함유 or 무설탕 선택가능)
#
#                                                      purchase_url
# 94   https://smartstore.naver.com/monil2house/products/8606793020
# 23   https://smartstore.naver.com/monil2house/products/8606659063
# 147  https://smartstore.naver.com/monil2house/products/9935315681
#  ------------------------
# Query Item:
#   title                                               노밀가루 국산 쌀가루 글루텐프리 휘낭시에
# purchase_url    https://smartstore.naver.com/b__ethel/products/10159951916
# Name: 63, dtype: object
# Recommendation Items:
#                                 title  \
# 174  [모닐이네하우스] 겉바속촉 쌀 휘낭시에 시리즈 글루텐프리
#
#                                                      purchase_url
# 174  https://smartstore.naver.com/monil2house/products/8658325289
#  ------------------------
# Query Item:
#   title                                  비건 유기농 쌀 & 완두단백 & 제로슈가 프로틴볼 글루텐프리
# purchase_url    https://smartstore.naver.com/meandri/products/8725650510
# Name: 64, dtype: object
# Recommendation Items:
#  Empty DataFrame
# Columns: [title, purchase_url]
# Index: []
#  ------------------------
# Query Item:
#   title                            [통밀식빵2개+아침한톨 땅콩초코맛 스프레드1개 세트 ] 땅콩잼 더브레드블루X푸로운
# purchase_url    https://smartstore.naver.com/thebreadblue/products/10607885526
# Name: 65, dtype: object
# Recommendation Items:
#                                               title  \
# 95  [치아바타 3종+아침한톨 땅콩초코맛 스프레드1개 세트 ] 땅콩잼 더브레드블루X푸로운
#
#                                                       purchase_url
# 95  https://smartstore.naver.com/thebreadblue/products/10607873147
#  ------------------------
# Query Item:
#   title                                                              메종드비건 홀파운드케이크
# purchase_url    https://smartstore.naver.com/maison_de_vegan/products/4788638756
# Name: 66, dtype: object
# Recommendation Items:
#                                                 title  \
# 47                    비건이레 비건빵 글루텐프리 홀파운드케이크 쑥무화과파운드
# 136              틴베이크 프로틴 단백질 플틴 바나나 파운드 케이크 식사 식단 빵
# 163  [포포브레드] 홀 파운드 3종 / 크리스마스 글루텐프리 케이크 노밀가루 비건 베이커리
#
#                                                              purchase_url
# 47   https://smartstore.naver.com/vegan_for_sevendays/products/5493037223
# 136             https://smartstore.naver.com/teinbake/products/8698425868
# 163         https://smartstore.naver.com/forfourbread/products/6001277363
#  ------------------------
# Query Item:
#   title                프로넛 프로틴 오븐에 구운 도넛 카카오 밀가루없는 단백질 빵 식사대용 건강한 간식 글루텐프
# purchase_url    https://smartstore.naver.com/pronut/products/5874026105
# Name: 67, dtype: object
# Recommendation Items:
#                                                    title  \
# 192  [box] 프로넛 프로틴 도넛 카카오 밀가루없는 단백질 빵 식사대용 건강한 간식 글루텐프리
#
#                                                 purchase_url
# 192  https://smartstore.naver.com/pronut/products/7709134195
#  ------------------------
# Query Item:
#   title                     (1병+1병) 그림의빵 굿다운 1/9 저칼로리 저당 치아딸기잼, 서울어워드수상 당뇨와건강몰
# purchase_url    https://smartstore.naver.com/grimmsbread/products/8590293765
# Name: 68, dtype: object
# Recommendation Items:
#                                                   title  \
# 9   굿다운 1/9 저칼로리 저당 치아딸기잼, 서울어워드수상 당뇨와건강몰입점 스테비아잼 무설탕잼
# 24      굿다운 1/9저칼로리 저당 딸기잼 1kg 리필팩, 당뇨키토몰입점 스테비아잼 굿다운잼
# 25       그림의빵 완벽저당 전제품 맛보기 10개 세트(1/9딸기잼 포함), 당뇨와건강몰입점
#
#                                                     purchase_url
# 9   https://smartstore.naver.com/grimmsbread/products/7318233551
# 24  https://smartstore.naver.com/grimmsbread/products/9418851993
# 25  https://smartstore.naver.com/grimmsbread/products/8158079418
#  ------------------------
# Query Item:
#   title                                         노밀가루 프로틴 식빵 식단조절빵 식사빵 큐브식빵
# purchase_url    https://smartstore.naver.com/6-bbang/products/5554269016
# Name: 69, dtype: object
# Recommendation Items:
#  Empty DataFrame
# Columns: [title, purchase_url]
# Index: []
#  ------------------------
# Query Item:
#   title                              [모닐이네하우스] 수능 시험 합격 기원 쌀 디저트 특별 종합 선물세트 응원
# purchase_url    https://smartstore.naver.com/monil2house/products/8671269188
# Name: 70, dtype: object
# Recommendation Items:
#  Empty DataFrame
# Columns: [title, purchase_url]
# Index: []
#  ------------------------
# Query Item:
#   title                                 플레인 프프쿠키 프로틴빵 고단백 수제 글루텐프리 non-gmo
# purchase_url    https://smartstore.naver.com/f_nergy/products/6643631916
# Name: 71, dtype: object
# Recommendation Items:
#                                             title  \
# 109            네플스콘 프로틴빵 플레인 고단백 수제 글루텐프리스콘 골라담기
# 200  초콩머핀 초코 프로틴빵 고단백 수제 글루텐프리 병아리콩 non-gmo 골라담기
#
#                                                  purchase_url
# 109  https://smartstore.naver.com/f_nergy/products/7553645822
# 200  https://smartstore.naver.com/f_nergy/products/5759900876
#  ------------------------
# Query Item:
#   title                                                  초코 부에노 저당 간식 비건쿠키
# purchase_url    https://smartstore.naver.com/veganez/products/9899516906
# Name: 72, dtype: object
# Recommendation Items:
#                               title  \
# 188  비건이지 저당 쿠키 건강 간식 아몬드 초코칩 비건쿠키
# 140           저당 간식 쿠키 피넛 초코칩 땅콩쿠키
# 85      얼그레이 초코볼 볼쿠키 비건쿠키 저당 글루텐프리
#
#                                                  purchase_url
# 188  https://smartstore.naver.com/veganez/products/9932836164
# 140  https://smartstore.naver.com/veganez/products/9931974653
# 85   https://smartstore.naver.com/veganez/products/9899451546
#  ------------------------
# Query Item:
#   title                                     무설탕 프로틴 수제 키토 그래놀라 4종 270g 당일 로스팅
# purchase_url    https://smartstore.naver.com/ketopantry/products/7347002964
# Name: 73, dtype: object
# Recommendation Items:
#  Empty DataFrame
# Columns: [title, purchase_url]
# Index: []
#  ------------------------
# Query Item:
#   title                                           무설탕 비건이지 현미 쌀 크런치 크럼블 크럼볼
# purchase_url    https://smartstore.naver.com/veganez/products/10254446850
# Name: 74, dtype: object
# Recommendation Items:
#                                    title  \
# 178  무설탕 비건이지 먹어 볼 쿠키 플레인 쌀 크럼블 크럼볼 노슈가
# 186      크럼블 크럼볼 흑임자 아몬드 무설탕 비건이지 임자몬드볼
#
#                                                   purchase_url
# 178  https://smartstore.naver.com/veganez/products/10248863765
# 186  https://smartstore.naver.com/veganez/products/10367728906
#  ------------------------
# Query Item:
#   title                                   [달콤 통밀 크럼블] 더브레드블루 비건빵 건강간식 통밀 건강 식사대용
# purchase_url    https://smartstore.naver.com/thebreadblue/products/10612945426
# Name: 75, dtype: object
# Recommendation Items:
#                                        title  \
# 108  [통밀 어니언 베이글] 더브레드블루 비건빵 건강빵 건강간식 저요오드식
# 76     [프랑스 바게트] 더브레드블루 비건빵 건강간식 저당 건강 식사대용
# 114     [호두 깜빠뉴] 더브레드블루 비건빵 건강간식 저당 건강 식사대용
#
#                                                        purchase_url
# 108  https://smartstore.naver.com/thebreadblue/products/10638031009
# 76   https://smartstore.naver.com/thebreadblue/products/10638101379
# 114  https://smartstore.naver.com/thebreadblue/products/10638548817
#  ------------------------
# Query Item:
#   title                                     [프랑스 바게트] 더브레드블루 비건빵 건강간식 저당 건강 식사대용
# purchase_url    https://smartstore.naver.com/thebreadblue/products/10638101379
# Name: 76, dtype: object
# Recommendation Items:
#                                         title  \
# 196  [무화과 듬뿍 바게트] 더브레드블루 비건빵 건강간식 저당 건강 식사대용
# 114      [호두 깜빠뉴] 더브레드블루 비건빵 건강간식 저당 건강 식사대용
# 127       [호밀100] 더브레드블루 비건빵 건강간식 저당 건강 식사대용
#
#                                                        purchase_url
# 196  https://smartstore.naver.com/thebreadblue/products/10615189592
# 114  https://smartstore.naver.com/thebreadblue/products/10638548817
# 127  https://smartstore.naver.com/thebreadblue/products/10638521377
#  ------------------------
# Query Item:
#   title                                                      약과 쿠키 영양 간식 건강 디저트
# purchase_url    https://smartstore.naver.com/thebreadblue/products/8535025982
# Name: 77, dtype: object
# Recommendation Items:
#                                          title  \
# 44                클래식 소보로빵 비건빵 100% 건강빵 영양 간식
# 91          클래식 단팥빵 비건빵 100% 건강빵 영양 간식 더브레드블루
# 46  [클래식 단팥빵 5개 세트] 비건빵 100% 건강빵 영양 간식 더브레드블루
#
#                                                       purchase_url
# 44   https://smartstore.naver.com/thebreadblue/products/8605330694
# 91   https://smartstore.naver.com/thebreadblue/products/8605319670
# 46  https://smartstore.naver.com/thebreadblue/products/10437959557
#  ------------------------
# Query Item:
#   title                                         [매콤한 올리브 치아바타] 저당빵 비건 치아바타 샌드위치빵
# purchase_url    https://smartstore.naver.com/thebreadblue/products/10217253433
# Name: 78, dtype: object
# Recommendation Items:
#                                      title  \
# 120                            올리브 쌀 치아바타
# 198  [포포브레드] 쌀 치아바타 4종 / 빵 무설탕 저염 비건 베이커리
# 123      올리브쌀 치아바타 비건빵 100% 쌀빵 건강빵 더브레드블루
#
#                                                          purchase_url
# 120  https://smartstore.naver.com/dearmyqueen1553/products/8089026511
# 198     https://smartstore.naver.com/forfourbread/products/5268761609
# 123     https://smartstore.naver.com/thebreadblue/products/5314453883
#  ------------------------
# Query Item:
#   title                                    프로틴 오트밀 초코칩쿠키 5개 식단조절 간식 무설탕 쿠키
# purchase_url    https://smartstore.naver.com/6-bbang/products/5399511173
# Name: 79, dtype: object
# Recommendation Items:
#                          title  \
# 140      저당 간식 쿠키 피넛 초코칩 땅콩쿠키
# 141  키토빵앗간 쿠키 (저당 글루텐프리 저탄수빵)
# 30      비건쿠키 글루텐프리 쌀 수제 건강 간식
#
#                                                     purchase_url
# 140     https://smartstore.naver.com/veganez/products/9931974653
# 141   https://smartstore.naver.com/ketobbang/products/6112318422
# 30   https://smartstore.naver.com/chopcookie/products/9606521978
#  ------------------------
# Query Item:
#   title                                                                   메종드비건 머핀
# purchase_url    https://smartstore.naver.com/maison_de_vegan/products/8166635657
# Name: 80, dtype: object
# Recommendation Items:
#  Empty DataFrame
# Columns: [title, purchase_url]
# Index: []
#  ------------------------
# Query Item:
#   title                               저당 단백질 식빵 플레인 당류 0.1g 무설탕, 무밀가루 식단빵 건강빵
# purchase_url    https://smartstore.naver.com/ketopantry/products/7330143587
# Name: 81, dtype: object
# Recommendation Items:
#  Empty DataFrame
# Columns: [title, purchase_url]
# Index: []
#  ------------------------
# Query Item:
#   title                                       글루텐프리빵 저당간식 아몬드가루빵 카스테라 파운드 - 크림치즈
# purchase_url    https://smartstore.naver.com/humming_pound/products/5469177664
# Name: 82, dtype: object
# Recommendation Items:
#  Empty DataFrame
# Columns: [title, purchase_url]
# Index: []
#  ------------------------
# Query Item:
#   title                           [더브레드블루 벨기에 초콜릿 비건케이크 1호] 생일 케이크 디저트(No우유계란버터)
# purchase_url    https://smartstore.naver.com/thebreadblue/products/10707527718
# Name: 83, dtype: object
# Recommendation Items:
#                                                  title  \
# 107  [더브레드블루 생크림 비건케이크 1호] 순식물성 생일 케이크 디저트(No 우유계란버터)
# 58                로투스 비스코프 비건케이크 더브레드블루 (No 계란 우유 버터)
#
#                                                        purchase_url
# 107  https://smartstore.naver.com/thebreadblue/products/10707546419
# 58    https://smartstore.naver.com/thebreadblue/products/8215949572
#  ------------------------
# Query Item:
#   title                                          프로틴스콘 노밀가루 노설탕 식단조절 간식 스콘
# purchase_url    https://smartstore.naver.com/6-bbang/products/5374954271
# Name: 84, dtype: object
# Recommendation Items:
#                                     title  \
# 126                   비건 스콘 비건빵 팥이랑밤이레스콘
# 49   틴베이크 플틴스콘 수제 고단백 프로틴 통밀빵 단백질 플레인 스콘
# 57                               메종드비건스콘
#
#                                                              purchase_url
# 126  https://smartstore.naver.com/vegan_for_sevendays/products/5487644794
# 49              https://smartstore.naver.com/teinbake/products/6206497546
# 57       https://smartstore.naver.com/maison_de_vegan/products/4780918604
#  ------------------------
# Query Item:
#   title                                         얼그레이 초코볼 볼쿠키 비건쿠키 저당 글루텐프리
# purchase_url    https://smartstore.naver.com/veganez/products/9899451546
# Name: 85, dtype: object
# Recommendation Items:
#                                  title  \
# 17          레몬 얼그레이 수제쿠키 쌀 글루텐프리 비건쿠키
# 162  저당 수제 간식 얼그레이 초코칩 글루텐프리 홍차 비건 쿠키
# 141          키토빵앗간 쿠키 (저당 글루텐프리 저탄수빵)
#
#                                                    purchase_url
# 17     https://smartstore.naver.com/veganez/products/9899464494
# 162    https://smartstore.naver.com/veganez/products/9899556578
# 141  https://smartstore.naver.com/ketobbang/products/6112318422
#  ------------------------
# Query Item:
#   title                                                                 돌체 로미아스 쿠키
# purchase_url    https://smartstore.naver.com/dearmyqueen1553/products/9313586200
# Name: 86, dtype: object
# Recommendation Items:
#  Empty DataFrame
# Columns: [title, purchase_url]
# Index: []
#  ------------------------
# Query Item:
#   title                                                                   메종드비건 큐브
# ...
# Recommendation Items:
#                               title  \
# 188  비건이지 저당 쿠키 건강 간식 아몬드 초코칩 비건쿠키
# 139         저당 비건 글루텐프리 간식 피넛버터 쿠키
# 72               초코 부에노 저당 간식 비건쿠키
#
#                                                  purchase_url
# 188  https://smartstore.naver.com/veganez/products/9932836164
# 139  https://smartstore.naver.com/veganez/products/9954247586
# 72   https://smartstore.naver.com/veganez/products/9899516906
#  ------------------------
# Query Item:
#   title                                            저당 프로틴 스콘 무설탕 고댠백 수제 건강 간식
# purchase_url    https://smartstore.naver.com/ketopantry/products/9764856488
# Name: 184, dtype: object
# Recommendation Items:
#                                   title  \
# 109  네플스콘 프로틴빵 플레인 고단백 수제 글루텐프리스콘 골라담기
#
#                                                  purchase_url
# 109  https://smartstore.naver.com/f_nergy/products/7553645822
#  ------------------------
# Query Item:
#   title                                                         구떼 비건 스모어 쿠키 4종
# purchase_url    https://smartstore.naver.com/gouterbakery/products/8421111962
# Name: 185, dtype: object
# Recommendation Items:
#                       title  \
# 125  비건 글루텐 프리 마들렌 8종 (2P)
#
#                                                       purchase_url
# 125  https://smartstore.naver.com/gouterbakery/products/8015684149
#  ------------------------
# Query Item:
#   title                                      크럼블 크럼볼 흑임자 아몬드 무설탕 비건이지 임자몬드볼
# purchase_url    https://smartstore.naver.com/veganez/products/10367728906
# Name: 186, dtype: object
# Recommendation Items:
#                                    title  \
# 74            무설탕 비건이지 현미 쌀 크런치 크럼블 크럼볼
# 178  무설탕 비건이지 먹어 볼 쿠키 플레인 쌀 크럼블 크럼볼 노슈가
#
#                                                   purchase_url
# 74   https://smartstore.naver.com/veganez/products/10254446850
# 178  https://smartstore.naver.com/veganez/products/10248863765
#  ------------------------
# Query Item:
#   title                                      [감자 치아바타] 저당빵, 비건빵, 건강빵 식사대용 더브레드블루
# purchase_url    https://smartstore.naver.com/thebreadblue/products/10217185928
# Name: 187, dtype: object
# Recommendation Items:
#                                      title  \
# 76   [프랑스 바게트] 더브레드블루 비건빵 건강간식 저당 건강 식사대용
# 114   [호두 깜빠뉴] 더브레드블루 비건빵 건강간식 저당 건강 식사대용
# 127    [호밀100] 더브레드블루 비건빵 건강간식 저당 건강 식사대용
#
#                                                        purchase_url
# 76   https://smartstore.naver.com/thebreadblue/products/10638101379
# 114  https://smartstore.naver.com/thebreadblue/products/10638548817
# 127  https://smartstore.naver.com/thebreadblue/products/10638521377
#  ------------------------
# Query Item:
#   title                                      비건이지 저당 쿠키 건강 간식 아몬드 초코칩 비건쿠키
# purchase_url    https://smartstore.naver.com/veganez/products/9932836164
# Name: 188, dtype: object
# Recommendation Items:
#                                  title  \
# 72                  초코 부에노 저당 간식 비건쿠키
# 183  [비건 쿠키] 건강 간식, 영양 간식, 채식, 식물성 쿠키
# 85         얼그레이 초코볼 볼쿠키 비건쿠키 저당 글루텐프리
#
#                                                       purchase_url
# 72        https://smartstore.naver.com/veganez/products/9899516906
# 183  https://smartstore.naver.com/thebreadblue/products/9686069150
# 85        https://smartstore.naver.com/veganez/products/9899451546
#  ------------------------
# Query Item:
#   title                                      [모닐이네하우스] Best 100% 쌀 소금빵 (글루텐프리)
# purchase_url    https://smartstore.naver.com/monil2house/products/8907264126
# Name: 189, dtype: object
# Recommendation Items:
#                                          title  \
# 10         [모닐이네하우스] 글루텐프리 100% 쌀 소금빵 5개 세트구성
# 152  [모닐이네하우스] 🌾 100% 글루텐프리 쌀로 만든 베이글 (비건/GF)
#
#                                                      purchase_url
# 10   https://smartstore.naver.com/monil2house/products/9108823733
# 152  https://smartstore.naver.com/monil2house/products/8866615221
#  ------------------------
# Query Item:
#   title                                                         비건 쌀 마들렌 - 콩고물 범벅 쑥
# purchase_url    https://smartstore.naver.com/dearmyqueen1553/products/10663557479
# Name: 190, dtype: object
# Recommendation Items:
#                    title  \
# 56   비건 쌀 마들렌 - 아마레또 커피
# 33    비건 쌀 마들렌 - 초코칩 초코
# 124            비건버터 쌀식빵
#
#                                                           purchase_url
# 56   https://smartstore.naver.com/dearmyqueen1553/products/10663549774
# 33   https://smartstore.naver.com/dearmyqueen1553/products/10663546111
# 124   https://smartstore.naver.com/dearmyqueen1553/products/9022144231
#  ------------------------
# Query Item:
#   title                                         글루텐프리 수제쿠키 저당 디저트맛집 마카다미아 쿠키-2개입
# purchase_url    https://smartstore.naver.com/humming_pound/products/5469178935
# Name: 191, dtype: object
# Recommendation Items:
#                                   title  \
# 133                      비건 아메리칸 쿠키 2종
# 141           키토빵앗간 쿠키 (저당 글루텐프리 저탄수빵)
# 31   [모닐이네하우스] 수제 쌀 르뱅 쿠키 시리즈 9종 글루텐프리
#
#                                                          purchase_url
# 133  https://smartstore.naver.com/dearmyqueen1553/products/8723454443
# 141        https://smartstore.naver.com/ketobbang/products/6112318422
# 31       https://smartstore.naver.com/monil2house/products/8623551874
#  ------------------------
# Query Item:
#   title                [box] 프로넛 프로틴 도넛 카카오 밀가루없는 단백질 빵 식사대용 건강한 간식 글루텐프리
# purchase_url    https://smartstore.naver.com/pronut/products/7709134195
# Name: 192, dtype: object
# Recommendation Items:
#                                                   title  \
# 67  프로넛 프로틴 오븐에 구운 도넛 카카오 밀가루없는 단백질 빵 식사대용 건강한 간식 글루텐프
#
#                                                purchase_url
# 67  https://smartstore.naver.com/pronut/products/5874026105
#  ------------------------
# Query Item:
#   title                     (3팩+3팩) 그림의빵 모닝빵 총 6팩, 저당식단용빵 100%곡물단백질 당뇨와건강몰입점 노
# purchase_url    https://smartstore.naver.com/grimmsbread/products/9718870989
# Name: 193, dtype: object
# Recommendation Items:
#                                                    title  \
# 197  그림의빵 코코모닝빵 3팩, 저당식단용빵 100%곡물단백질 당뇨와건강몰입점 노밀가루 저당 고
# 41   저당모닝빵4팩+저당딸기잼 1kg 리필팩 세트구성, 저칼로리잼, 100%곡물단백질, 당뇨키토
#
#                                                      purchase_url
# 197  https://smartstore.naver.com/grimmsbread/products/7318221629
# 41   https://smartstore.naver.com/grimmsbread/products/8248603713
#  ------------------------
# Query Item:
#   title                                           에이사 비건 크림치즈쿠키 글루텐프리 저오일 저당 저칼로리
# purchase_url    https://smartstore.naver.com/asa_veganclass/products/6149591370
# Name: 194, dtype: object
# Recommendation Items:
#                                  title  \
# 85         얼그레이 초코볼 볼쿠키 비건쿠키 저당 글루텐프리
# 141          키토빵앗간 쿠키 (저당 글루텐프리 저탄수빵)
# 51   비건 이지 뉴초콜렛칩 쿠키 노밀가루 쌀 글루텐프리 비건쿠키
#
#                                                    purchase_url
# 85     https://smartstore.naver.com/veganez/products/9899451546
# 141  https://smartstore.naver.com/ketobbang/products/6112318422
# 51    https://smartstore.naver.com/veganez/products/10464483924
#  ------------------------
# Query Item:
#   title                                          초콜렛칩 쿠키 노밀가루 쌀 글루텐프리 비건쿠키
# purchase_url    https://smartstore.naver.com/veganez/products/9899550033
# Name: 195, dtype: object
# Recommendation Items:
#                                 title  \
# 51  비건 이지 뉴초콜렛칩 쿠키 노밀가루 쌀 글루텐프리 비건쿠키
# 17         레몬 얼그레이 수제쿠키 쌀 글루텐프리 비건쿠키
# 85        얼그레이 초코볼 볼쿠키 비건쿠키 저당 글루텐프리
#
#                                                  purchase_url
# 51  https://smartstore.naver.com/veganez/products/10464483924
# 17   https://smartstore.naver.com/veganez/products/9899464494
# 85   https://smartstore.naver.com/veganez/products/9899451546
#  ------------------------
# Query Item:
#   title                                  [무화과 듬뿍 바게트] 더브레드블루 비건빵 건강간식 저당 건강 식사대용
# purchase_url    https://smartstore.naver.com/thebreadblue/products/10615189592
# Name: 196, dtype: object
# Recommendation Items:
#                                      title  \
# 76   [프랑스 바게트] 더브레드블루 비건빵 건강간식 저당 건강 식사대용
# 114   [호두 깜빠뉴] 더브레드블루 비건빵 건강간식 저당 건강 식사대용
# 127    [호밀100] 더브레드블루 비건빵 건강간식 저당 건강 식사대용
#
#                                                        purchase_url
# 76   https://smartstore.naver.com/thebreadblue/products/10638101379
# 114  https://smartstore.naver.com/thebreadblue/products/10638548817
# 127  https://smartstore.naver.com/thebreadblue/products/10638521377
#  ------------------------
# Query Item:
#   title                     그림의빵 코코모닝빵 3팩, 저당식단용빵 100%곡물단백질 당뇨와건강몰입점 노밀가루 저당 고
# purchase_url    https://smartstore.naver.com/grimmsbread/products/7318221629
# Name: 197, dtype: object
# Recommendation Items:
#                                                    title  \
# 193  (3팩+3팩) 그림의빵 모닝빵 총 6팩, 저당식단용빵 100%곡물단백질 당뇨와건강몰입점 노
# 41   저당모닝빵4팩+저당딸기잼 1kg 리필팩 세트구성, 저칼로리잼, 100%곡물단백질, 당뇨키토
#
#                                                      purchase_url
# 193  https://smartstore.naver.com/grimmsbread/products/9718870989
# 41   https://smartstore.naver.com/grimmsbread/products/8248603713
#  ------------------------
# Query Item:
#   title                                    [포포브레드] 쌀 치아바타 4종 / 빵 무설탕 저염 비건 베이커리
# purchase_url    https://smartstore.naver.com/forfourbread/products/5268761609
# Name: 198, dtype: object
# Recommendation Items:
#                                  title  \
# 123  올리브쌀 치아바타 비건빵 100% 쌀빵 건강빵 더브레드블루
# 78   [매콤한 올리브 치아바타] 저당빵 비건 치아바타 샌드위치빵
# 120                        올리브 쌀 치아바타
#
#                                                          purchase_url
# 123     https://smartstore.naver.com/thebreadblue/products/5314453883
# 78     https://smartstore.naver.com/thebreadblue/products/10217253433
# 120  https://smartstore.naver.com/dearmyqueen1553/products/8089026511
#  ------------------------
# Query Item:
#   title                프로넛 프로틴 큐브 파운드 밀가루없는 단백질 빵 에스프레소 식사대용 건강한 간식 글루텐프리
# purchase_url    https://smartstore.naver.com/pronut/products/6510327348
# Name: 199, dtype: object
# Recommendation Items:
#  Empty DataFrame
# Columns: [title, purchase_url]
# Index: []
#  ------------------------
# Query Item:
#   title                        초콩머핀 초코 프로틴빵 고단백 수제 글루텐프리 병아리콩 non-gmo 골라담기
# purchase_url    https://smartstore.naver.com/f_nergy/products/5759900876
# Name: 200, dtype: object
# Recommendation Items:
#                                            title  \
# 122  [빵어니스타] 비건 라미쿠키 개별 구매 페이지 (당일 미입금 시 주문 취소)
# 71           플레인 프프쿠키 프로틴빵 고단백 수제 글루텐프리 non-gmo
#
#                                                      purchase_url
# 122  https://smartstore.naver.com/shophonesta/products/6130615730
# 71       https://smartstore.naver.com/f_nergy/products/6643631916
#  ------------------------
# Query Item:
#   title                                   프로틴도넛 프로틴 노밀가루 무설탕 단백질 식단조절 단백질빵
# purchase_url    https://smartstore.naver.com/6-bbang/products/5847878830
# Name: 201, dtype: object
# Recommendation Items:
#  Empty DataFrame
# Columns: [title, purchase_url]
# Index: []
#  ------------------------
# Query Item:
#   title                              [모닐이네하우스] 무설탕 3단 초콜릿 케이크 DIY키트 (연말파티, 행사)
# purchase_url    https://smartstore.naver.com/monil2house/products/9324661358
# Name: 202, dtype: object
# Recommendation Items:
#                                                 title  \
# 23  [모닐이네하우스] 특허받은 레시피로 만든 무설탕, 노밀가루, 노생크림 갸또쇼콜라 시리즈
# 94  [모닐이네하우스] 특허 레시피로 만든 무설탕, 글루텐프리 2단 초콜릿 케이크 DIY키트
#
#                                                     purchase_url
# 23  https://smartstore.naver.com/monil2house/products/8606659063
# 94  https://smartstore.naver.com/monil2house/products/8606793020
#  ------------------------
# Query Item:
#   title                                             두바이 초콜릿 쌀 비건쿠키 글루텐프리 빵택배
# purchase_url    https://smartstore.naver.com/vegandaum/products/5675831093
# Name: 203, dtype: object
# Recommendation Items:
#                            title  \
# 4           꾸디 비건쿠키 (르뱅쿠키 수제쿠키)
# 128  비건이레 수제 비건 쿠키 얼그레이오망아메리칸쿠키
# 195   초콜렛칩 쿠키 노밀가루 쌀 글루텐프리 비건쿠키
#
#                                                              purchase_url
# 4                  https://smartstore.naver.com/ggudi/products/5350602475
# 128  https://smartstore.naver.com/vegan_for_sevendays/products/5954319644
# 195              https://smartstore.naver.com/veganez/products/9899550033
#  ------------------------
# Query Item:
#   title                              더블 초코칩 수제 비건쿠키 가나슈 초코 쫀득 꾸덕 결혼 답례품 선물
# purchase_url    https://smartstore.naver.com/veganez/products/9899534560
# Name: 204, dtype: object
# Recommendation Items:
#                                            title  \
# 122  [빵어니스타] 비건 라미쿠키 개별 구매 페이지 (당일 미입금 시 주문 취소)
#
#                                                      purchase_url
# 122  https://smartstore.naver.com/shophonesta/products/6130615730
#  ------------------------
# Query Item:
#   title                    비건이지 수제 쿠키 글루텐프리 무설탕 답례품 퇴사 선물 시보해제 결혼 조공 르뱅 간식
# purchase_url    https://smartstore.naver.com/veganez/products/9491948626
# Name: 205, dtype: object
# Recommendation Items:
#                                            title  \
# 122  [빵어니스타] 비건 라미쿠키 개별 구매 페이지 (당일 미입금 시 주문 취소)
#
#                                                      purchase_url
# 122  https://smartstore.naver.com/shophonesta/products/6130615730
#  ------------------------
# Query Item:
#   title                                                          로썸 통밀비스코티
# purchase_url    https://smartstore.naver.com/rawsome/products/6062750757
# Name: 206, dtype: object
# Recommendation Items:
#  Empty DataFrame
# Columns: [title, purchase_url]
# Index: []
#  ------------------------
# Query Item:
#   title                                                    빵떡집 단백질빵떡이 단백질10g 글루텐프리
# purchase_url    https://smartstore.naver.com/bbangttuk_house/products/9943459516
# Name: 207, dtype: object
# Recommendation Items:
#                            title  \
# 142  단백질 디저트 빵떡집 글루텐프리 단백질빵 빵떡이
#
#                                                           purchase_url
# 142  https://smartstore.naver.com/bbangttuk_house/products/10266867757
#  ------------------------
# Query Item:
#   title                                          [소소한 소금빵 4개 세트] 비건빵 100% 건강빵 간식
# purchase_url    https://smartstore.naver.com/thebreadblue/products/10437967700
# Name: 208, dtype: object
# Recommendation Items:
#                                           title  \
# 208            [소소한 소금빵 4개 세트] 비건빵 100% 건강빵 간식
# 138                    소소한 소금빵 비건빵 100% 건강빵 간식
# 46   [클래식 단팥빵 5개 세트] 비건빵 100% 건강빵 영양 간식 더브레드블루
#
#                                                        purchase_url
# 208  https://smartstore.naver.com/thebreadblue/products/10437967700
# 138   https://smartstore.naver.com/thebreadblue/products/7048770140
# 46   https://smartstore.naver.com/thebreadblue/products/10437959557
#  ------------------------
# Query Item:
#   title                               [포포브레드] 마들렌 4종 / 쌀 디저트 글루텐프리 노밀가루 비건 베이커리
# purchase_url    https://smartstore.naver.com/forfourbread/products/5268905112
# Name: 209, dtype: object
# Recommendation Items:
#                                      title  \
# 52   당류 0g 저당 마들렌 무설탕 무밀가루 고식이섬유 식단 간식 디저
# 170                         비건 쌀 마들렌 - 레몬
#
#                                                          purchase_url
# 52       https://smartstore.naver.com/ketopantry/products/10282880886
# 170  https://smartstore.naver.com/dearmyqueen1553/products/8769087196
#  ------------------------
# Query Item:
#   title                                  그림의빵 고단백 저당 크림빵 6개, 100%곡물단백 당뇨와건강몰입점
# purchase_url    https://smartstore.naver.com/grimmsbread/products/6541794870
# Name: 210, dtype: object
# Recommendation Items:
#                                                  title  \
# 110              그림의빵 고단백 저당 크림빵 9개,100%곡물단백 당뇨와건강몰입점
# 96   그림의빵 88kcal 저당 고단백 휘낭시에 12입, 당류0.3g 당뇨와건강몰입점 디저트
# 177   그림의빵 저당 고단백 라즈베리 초코 그낭시에 16입, 당뇨와건강몰입점 디저트 휘낭시에
#
#                                                      purchase_url
# 110  https://smartstore.naver.com/grimmsbread/products/8248624953
# 96   https://smartstore.naver.com/grimmsbread/products/8248643626
# 177  https://smartstore.naver.com/grimmsbread/products/9708208936
#  ------------------------
# 0.6398104265402843

# %%
from collections import Counter
agg_cnt = Counter(rec_list)

# %%
agg_df = pd.DataFrame.from_dict(agg_cnt, orient='index').reset_index()
agg_df.columns = ['id', 'count']
fig = plt.figure(figsize=(10, 6))
plt.bar(agg_df['id'], agg_df['count'])
# Out:
# <BarContainer object of 131 artists>
