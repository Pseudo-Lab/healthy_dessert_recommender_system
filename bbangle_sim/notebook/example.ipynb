# %%
import pandas as pd
from konlpy.tag import Okt
from numpy import ndarray
import warnings
import re 
from model.bow import BagOfWords
from model.tfidf import TfIdf
import yaml
warnings.filterwarnings("ignore")
# Out:
# C:\Users\gnsdl\AppData\Local\Temp\ipykernel_8904\2874203659.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
# config
with open('configs/database.yaml') as f:
    cfg = yaml.load(f, Loader=yaml.FullLoader)

# %%
from utils.query_service import QueryService
query_service = QueryService(cfg['mysql'])

# %%
query_service.query_to_pandas_df('Show tables')
# Out:
#               Tables_in_bakery
# 0   board_preference_statistic
# 1              board_statistic
# 2                  food_survey
# 3                        image
# 4                       member
# 5            member_preference
# 6                       notice
# 7                   preference
# 8                      product
# 9                product_board
# 10              product_detail
# 11                 product_img
# 12                        push
# 13                   push_date
# 14                random_board
# 15               refresh_token
# 16                      review
# 17                  review_img
# 18                 review_like
# 19                      search
# 20         signature_agreement
# 21                       store
# 22                  test_store
# 23             wishlist_folder
# 24            wishlist_product
# 25              wishlist_store
# 26                  withdrawal

# %%
PRODUCT_BOARD_SQL = """
SELECT id
, store_id
, title
, price
, is_soldout
, view 
FROM product_board
"""
product_board = query_service.query_to_pandas_df(PRODUCT_BOARD_SQL)

# %%
PRODUCT_SQL = """
SELECT id
, product_board_id
, title as option
, price as option_price
, category
, gluten_free_tag
, high_protein_tag
, sugar_free_tag
, vegan_tag
, ketogenic_tag
FROM product
"""
product = query_service.quaery_to_pandas_df(PRODUCT_SQL)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 14
#       1 PRODUCT_SQL = """
#       2 SELECT id
#       3 , product_board_id
#    (...)
#      12 FROM product
#      13 """
# ---> 14 product = query_service.quaery_to_pandas_df(PRODUCT_SQL)
#
# AttributeError: 'QueryService' object has no attribute 'quaery_to_pandas_df'

# %%
REVIEW_SQL = """
SELECT board_id
, badge_taste
, badge_brix
, badge_texture
, rate
, content
FROM review
"""
review = query_service.query_to_pandas_df(REVIEW_SQL)
review = review.drop_duplicates(subset=['board_id', 'content'], keep='first')

# %%
BOARD_STAT_SQL = """
SELECT board_id
, board_review_grade
, board_view_count
, board_review_count
, board_wish_count 
FROM board_statistic
"""
board_stat = query_service.query_to_pandas_df(BOARD_STAT_SQL)

# %%
# board_id가 각 preference_type마다 얼만큼의 preference_score를 갖는지
# 아직 신뢰성있는 데이터로 보이진 않음 (샘플이 적고 score의 분산이 너무 큼)
BOARD_PREFERENCE_STAT_SQL = """
SELECT board_id
, preference_score
, preference_type
, preference_weight
FROM board_preference_statistic
ORDER BY board_id
"""
board_preference_stat = query_service.query_to_pandas_df(BOARD_PREFERENCE_STAT_SQL)

# %% [markdown]
# #### Data Import

# %%
df = pd.read_csv('data/product_board_feature.csv', encoding='utf-8')

# %%
# NLP 
okt = Okt()
def tokenize(text):
    return ['/'.join(t) for t in okt.pos(text, norm=True, stem=True)]

# 자연어 데이터만 추출
nl_df = df[['id', 'title', 'flavor']]

# %%
nl_df['title'] = nl_df['title'].astype(str)
nl_df['flavor'] = nl_df['flavor'].astype(str)

# %% [markdown]
# #### Preprocessing

# %%
# 소문자로 변환
nl_df['title'] = nl_df['title'].str.lower()
nl_df['flavor'] = nl_df['flavor'].str.lower()

# %%
# 특수문자 제거
special_chars = '[^가-힣0-9a-zA-Z]'
nl_df['title'] = nl_df['title'].apply(lambda x: re.sub(special_chars, ' ', x))
nl_df['flavor'] = nl_df['flavor'].apply(lambda x: re.sub(special_chars, ' ', x))

# %%
# preprocessing Rule
# 목적 : token이 될 수 있는 유효한 단어만 남기기 위해 불필요한 단어의 종류를 정의하고 제거한다.
# 수량 제거
quantity_compiler = re.compile(r'\d+[개입|kg|팩|개|종|입|원|g]+')
nl_df['title'] = nl_df['title'].apply(lambda x: re.sub(quantity_compiler, ' ', x))
nl_df['flavor'] = nl_df['flavor'].apply(lambda x: re.sub(quantity_compiler, ' ', x))

# %%
# title과 option을 합쳐서 description을 만든다.
nl_df['description'] = nl_df['title'] + ' ' + nl_df['flavor']

# %%
# tokenizing
nl_df['token'] = nl_df['description'].apply(lambda x: okt.morphs(x))

# %%
# 중복 단어 제거 : 나열식의 중복 단어가 노이즈로 인식됨 
nl_df['token'] = nl_df['token'].apply(lambda x: list(set(x)))

# %%
# stopwords 제거
with open('data/stopwords.txt', 'r', encoding='utf-8') as f:
    stopwords = f.readlines()
    stopwords = [x.strip() for x in stopwords]
nl_df['token'] = nl_df['token'].apply(lambda x: [word for word in x if word not in stopwords])

# %%
# description mutation : 
nl_df['description'] = nl_df['token'].apply(lambda x: ' '.join(x))

# %%
# id2idx
id2idx = {id:idx for idx, id in enumerate(nl_df['id'])}
idx2id = {idx:id for idx, id in enumerate(nl_df['id'])}

# %%
board_id_2_store_id = {board_id:store_id for board_id, store_id in zip(df['id'], df['store_id'])}

# %%
description = nl_df.set_index('id').to_dict()['title']
# import json
# with open('data/description.json', 'w', encoding='utf-8') as f:
#     json.dump(description, f)

# %% [markdown]
# #### Fit
# - 현재 있는 모델은 tfidf, bow입니다.
# - 아래의 예시처럼 model.fit()에 description 컬럼을 넣는다고 생각하시면 됩니다.

# %%
tfidf = TfIdf()
tfidf.fit(nl_df['description'])
tfidf.predict(1)
# Out:
# [(18, 0.40174844125052417),
#  (27, 0.2529894330230058),
#  (64, 0.2420079329174314),
#  (85, 0.18994660095218632),
#  (54, 0.16220861905396078),
#  (143, 0.15885571639989043),
#  (141, 0.15235309711767359),
#  (206, 0.14804650603794528),
#  (0, 0.14365131675828186),
#  (30, 0.1435167876245107)]

# %%
bow = BagOfWords()
bow.fit(nl_df['description'])
bow.predict(1)
# Out:
# [(18, 0.483045891539648),
#  (27, 0.4409585518440984),
#  (85, 0.4123930494211613),
#  (125, 0.3779644730092272),
#  (64, 0.36313651960128146),
#  (141, 0.3504383220252312),
#  (162, 0.3450327796711771),
#  (55, 0.3380617018914066),
#  (17, 0.329914439536929),
#  (155, 0.329914439536929)]

# %% [markdown]
# #### Generate

# %%
def generate_recommendation(board_id: int, cosine_sim: ndarray=None, top_k: int=10, threshold: float=0.5) -> list:
    """
    1. 추천을 생성한다
    2. thresholding을 한다 
    3. 같은 스토어 상품을 제외한다
    4. topk를 뽑는다
        - 안되면 예외처리한다
    :params:
        id : int : product id
        cosine_sim : ndarray : cosine similarity matrix
        top_k : int : number of recommendation
        threshold : float : similarity threshold
    :return:
    """
    idx = id2idx[board_id]
    sim_scores = list(enumerate(cosine_sim[idx]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True) # score 기준으로 정렬
    sim_scores = [i for i in sim_scores if i[1] > threshold]
    sim_scores = sim_scores[1:top_k+1] 
    candidate = [(board_id, idx2id[i], score) for i, score in sim_scores] # id, score 형태로 변환 
    product_indices = [i[0] for i in sim_scores]
    # print(product_indices)
    print('Query Item:\n ', df[['title', 'purchase_url']].iloc[idx])
    print('Recommendation Items:\n', df[['title', 'purchase_url']].iloc[product_indices], '\n', '------------------------')
    return candidate

# %%
result = generate_recommendation(board_id=15, cosine_sim=tfidf.cosine_matrix, top_k=3)
# Out:
# Recommendation Items:
#          title  \
# 124  비건버터 쌀식빵
#
#                                                          purchase_url
# 124  https://smartstore.naver.com/dearmyqueen1553/products/9022144231

# %%
result = generate_recommendation(board_id=5, cosine_sim=bow.cosine_matrix, top_k=3)
# Out:
# Query Item:
#   title                                         꾸디 비건쿠키 (르뱅쿠키 수제쿠키)
# purchase_url    https://smartstore.naver.com/ggudi/products/53...
# Name: 4, dtype: object
# Recommendation Items:
#                           title  \
# 166      스모어쿠키 르뱅 수제 아메리칸 비건쿠키
# 17   레몬 얼그레이 수제쿠키 쌀 글루텐프리 비건쿠키
#
#                                           purchase_url
# 166  https://smartstore.naver.com/veganez/products/...
# 17   https://smartstore.naver.com/veganez/products/...
#  ------------------------

# %% [markdown]
# #### Postprocessing
# - 같은 스토어의 제품은 나오지 않게 한다
# - 품절된 상품은 나오지 않게 한다

# %%
board_id_2_store_id = {board_id:store_id for board_id, store_id in zip(df['id'], df['store_id'])}
def store_exist(board_id:int, recommended_store_id_set: set)->bool:
    store_id = board_id_2_store_id.get(board_id, None)
    return store_id in recommended_store_id_set

from collections import defaultdict
# boardid가 같은 storeid를 갖고있는지 확인
recommend_dict = defaultdict(list)
recommended_store_id_set = set()
for board_id, recommendation_board_id, score in result:
    recommended_store_id = board_id_2_store_id.get(recommendation_board_id, None)
    if len(recommend_dict[board_id]) < 3:
        if not store_exist(recommendation_board_id, recommended_store_id_set):
            recommended_store_id_set.add(recommended_store_id)
            recommend_dict[board_id].append((recommendation_board_id, score))

# %% [markdown]
# #### Metrics

# %%
from metrics.coverage import get_coverage
from collections import defaultdict 
rec_result = defaultdict(list)
total_cnt = nl_df['id'].nunique()
rec_list = []
for board_id in nl_df['id']:
    result = generate_recommendation(board_id, bow.cosine_matrix, 3)
    rec_result[board_id].extend(result)
    rec_list.extend([x[1] for x in result])
rec_set = set(rec_list)
get_coverage(rec_set, total_cnt)
# Out:
# Query Item:
#   title                            냥빵 파운드 저탄수 대체당 제로 빵 글루텐프리 건강빵 비건
# purchase_url    https://smartstore.naver.com/nyangppang/produc...
# Name: 0, dtype: object
# Recommendation Items:
#                              title  \
# 135              비건 글루텐프리 베이글 [쑥]
# 42   카카오 큐브 대체당 냥빵 글루텐프리 대체당 노밀가루
# 26              비건 글루텐프리 베이글 [호박]
#
#                                           purchase_url
# 135  https://smartstore.naver.com/dearmyqueen1553/p...
# 42   https://smartstore.naver.com/nyangppang/produc...
# 26   https://smartstore.naver.com/dearmyqueen1553/p...
#  ------------------------
# Query Item:
#   title                        비건 유기농 쌀 & 기장쌀 잡곡 비스코티 5종 미앤드리 글루텐프리
# purchase_url    https://smartstore.naver.com/meandri/products/...
# Name: 1, dtype: object
# Recommendation Items:
#  Empty DataFrame
# Columns: [title, purchase_url]
# Index: []
#  ------------------------
# Query Item:
#   title                       비건이레 비건케이크 글루텐프리 떠먹는케이크 얼그레이아몬드베린느 GF
# purchase_url    https://smartstore.naver.com/vegan_for_sevenda...
# Name: 2, dtype: object
# Recommendation Items:
#  Empty DataFrame
# Columns: [title, purchase_url]
# Index: []
#  ------------------------
# Query Item:
#   title                    프로넛 무설탕 자일리톨 캔디 레몬 선물 사탕 금연 양치 아이간식 어린이집
# purchase_url    https://smartstore.naver.com/pronut/products/9...
# Name: 3, dtype: object
# Recommendation Items:
#  Empty DataFrame
# Columns: [title, purchase_url]
# Index: []
#  ------------------------
# Query Item:
#   title                                         꾸디 비건쿠키 (르뱅쿠키 수제쿠키)
# purchase_url    https://smartstore.naver.com/ggudi/products/53...
# Name: 4, dtype: object
# Recommendation Items:
#                           title  \
# 166      스모어쿠키 르뱅 수제 아메리칸 비건쿠키
# 17   레몬 얼그레이 수제쿠키 쌀 글루텐프리 비건쿠키
#
#                                           purchase_url
# 166  https://smartstore.naver.com/veganez/products/...
# 17   https://smartstore.naver.com/veganez/products/...
#  ------------------------
# Query Item:
#   title                        [쌀낭시에 5종x2개입] 비건빵 글루텐프리 쌀빵 휘낭시에 건강간식
# purchase_url    https://smartstore.naver.com/thebreadblue/prod...
# Name: 5, dtype: object
# Recommendation Items:
#                              title  \
# 28   현미 카스테라 비건빵 글루텐프리 쌀빵 디저트 건강빵
# 138       소소한 소금빵 비건빵 100% 건강빵 간식
# 44    클래식 소보로빵 비건빵 100% 건강빵 영양 간식
#
#                                           purchase_url
# 28   https://smartstore.naver.com/thebreadblue/prod...
# 138  https://smartstore.naver.com/thebreadblue/prod...
# 44   https://smartstore.naver.com/thebreadblue/prod...
#  ------------------------
# Query Item:
#   title                     꾸디 이달의 비건디저트 (비건쿠키 비건빵 베이커리 웨딩임페리얼 무화과)
# purchase_url    https://smartstore.naver.com/ggudi/products/65...
# Name: 6, dtype: object
# Recommendation Items:
#                           title  \
# 29  무설탕 비건베이커리 디저트 빵 간식 흑임자 쿠키
#
#                                          purchase_url
# 29  https://smartstore.naver.com/veganez/products/...
#  ------------------------
# Query Item:
#   title                          [통밀발효종빵 3개 세트] 속이 편안한 통밀발효종 건강 비건빵
# purchase_url    https://smartstore.naver.com/thebreadblue/prod...
# Name: 7, dtype: object
# Recommendation Items:
#                                            title  \
# 8    [발효종 순수 통밀빵 2개입 1세트] 저당빵 비건 건강 식사대용 더브레드블루
# 113            [소소한 소금빵 10개 세트] 비건빵 100% 건강빵 간식
# 208             [소소한 소금빵 4개 세트] 비건빵 100% 건강빵 간식
#
#                                           purchase_url
# 8    https://smartstore.naver.com/thebreadblue/prod...
# 113  https://smartstore.naver.com/thebreadblue/prod...
# 208  https://smartstore.naver.com/thebreadblue/prod...
#  ------------------------
# Query Item:
#   title                  [발효종 순수 통밀빵 2개입 1세트] 저당빵 비건 건강 식사대용 더브레드블루
# purchase_url    https://smartstore.naver.com/thebreadblue/prod...
# Name: 8, dtype: object
# Recommendation Items:
#                                         title  \
# 75    [달콤 통밀 크럼블] 더브레드블루 비건빵 건강간식 통밀 건강 식사대용
# 97   [밤식빵] 식사대용 비건 건강 통밤 소화잘되는 더브레드블루 (280g)
# 187      [감자 치아바타] 저당빵, 비건빵, 건강빵 식사대용 더브레드블루
#
#                                           purchase_url
# 75   https://smartstore.naver.com/thebreadblue/prod...
# 97   https://smartstore.naver.com/thebreadblue/prod...
# 187  https://smartstore.naver.com/thebreadblue/prod...
#  ------------------------
# Query Item:
#   title           굿다운 1/9 저칼로리 저당 치아딸기잼, 서울어워드수상 당뇨와건강몰입점 스테비아잼 ...
# purchase_url    https://smartstore.naver.com/grimmsbread/produ...
# Name: 9, dtype: object
# Recommendation Items:
#                                                   title  \
# 68   (1병+1병) 그림의빵 굿다운 1/9 저칼로리 저당 치아딸기잼, 서울어워드수상 당뇨...
# 24      굿다운 1/9저칼로리 저당 딸기잼 1kg 리필팩, 당뇨키토몰입점 스테비아잼 굿다운잼
# 182                                     굿다운 저당 초코잼, 1병
#
#                                           purchase_url
# 68   https://smartstore.naver.com/grimmsbread/produ...
# 24   https://smartstore.naver.com/grimmsbread/produ...
# 182  https://smartstore.naver.com/grimmsbread/produ...
#  ------------------------
# Query Item:
#   title                          [모닐이네하우스] 글루텐프리 100% 쌀 소금빵 5개 세트구성
# purchase_url    https://smartstore.naver.com/monil2house/produ...
# Name: 10, dtype: object
# Recommendation Items:
#                                   title  \
# 189  [모닐이네하우스] Best 100% 쌀 소금빵 (글루텐프리)
#
#                                           purchase_url
# 189  https://smartstore.naver.com/monil2house/produ...
#  ------------------------
# Query Item:
#   title                                          콩볼 쿠키볼 / 로키 오트밀 쿠키
# purchase_url    https://smartstore.naver.com/rawsome/products/...
# Name: 11, dtype: object
# Recommendation Items:
#  Empty DataFrame
# Columns: [title, purchase_url]
# Index: []
#  ------------------------
# Query Item:
#   title                              키토빵앗간 고메버터 파운드 (저당 글루텐프리 저탄수빵)
# purchase_url    https://smartstore.naver.com/ketobbang/product...
# Name: 12, dtype: object
# Recommendation Items:
#                                 title  \
# 175  키토빵앗간 큐브 앙금 파운드 (저당 글루텐프리 저탄수빵)
# 179   키토빵앗간 디쉬 치즈 스콘 (저당 글루텐프리 저탄수빵)
# 141         키토빵앗간 쿠키 (저당 글루텐프리 저탄수빵)
#
#                                           purchase_url
# 175  https://smartstore.naver.com/ketobbang/product...
# 179  https://smartstore.naver.com/ketobbang/product...
# 141  https://smartstore.naver.com/ketobbang/product...
#  ------------------------
# Query Item:
#   title                         저당 단백 모닝빵 5개입 무설탕 무밀가루 저당질 프로틴 단백질빵
# purchase_url    https://smartstore.naver.com/ketopantry/produc...
# Name: 13, dtype: object
# Recommendation Items:
#                                   title  \
# 173  당류 0g 저당 단백질 깜빠뉴 무설탕 무밀가루 비건 키토제닉
#
#                                           purchase_url
# 173  https://smartstore.naver.com/ketopantry/produc...
#  ------------------------
# Query Item:
#   title                                                수제 비건버터 쌀소금빵
# purchase_url    https://smartstore.naver.com/dearmyqueen1553/p...
# Name: 14, dtype: object
# Recommendation Items:
#                    title                                       purchase_url
# 124            비건버터 쌀식빵  https://smartstore.naver.com/dearmyqueen1553/p...
# 33    비건 쌀 마들렌 - 초코칩 초코  https://smartstore.naver.com/dearmyqueen1553/p...
# 56   비건 쌀 마들렌 - 아마레또 커피  https://smartstore.naver.com/dearmyqueen1553/p...
#  ------------------------
# Query Item:
#   title                          [빵어니스타] 비건 쌀 빠삭쿠키 (당일 미입금 시 주문 취소)
# purchase_url    https://smartstore.naver.com/shophonesta/produ...
# Name: 15, dtype: object
# Recommendation Items:
#                                            title  \
# 122  [빵어니스타] 비건 라미쿠키 개별 구매 페이지 (당일 미입금 시 주문 취소)
#
#                                           purchase_url
# 122  https://smartstore.naver.com/shophonesta/produ...
#  ------------------------
# Query Item:
#   title                                 카라멜 피칸 견과 쿠키 퇴사 답례품 선물 비건쿠키
# purchase_url    https://smartstore.naver.com/veganez/products/...
# Name: 16, dtype: object
# Recommendation Items:
#  Empty DataFrame
# Columns: [title, purchase_url]
# Index: []
#  ------------------------
# Query Item:
#   title                                   레몬 얼그레이 수제쿠키 쌀 글루텐프리 비건쿠키
# purchase_url    https://smartstore.naver.com/veganez/products/...
# Name: 17, dtype: object
# Recommendation Items:
#                                  title  \
# 162  저당 수제 간식 얼그레이 초코칩 글루텐프리 홍차 비건 쿠키
# 85         얼그레이 초코볼 볼쿠키 비건쿠키 저당 글루텐프리
# 195         초콜렛칩 쿠키 노밀가루 쌀 글루텐프리 비건쿠키
#
#                                           purchase_url
# 162  https://smartstore.naver.com/veganez/products/...
# 85   https://smartstore.naver.com/veganez/products/...
# 195  https://smartstore.naver.com/veganez/products/...
#  ------------------------
# Query Item:
#   title                            비건 유기농 쌀 제로슈가 고구마브라우니 미앤드리 글루텐프리
# purchase_url    https://smartstore.naver.com/meandri/products/...
# Name: 18, dtype: object
# Recommendation Items:
#                                  title  \
# 64  비건 유기농 쌀 & 완두단백 & 제로슈가 프로틴볼 글루텐프리
#
#                                          purchase_url
# 64  https://smartstore.naver.com/meandri/products/...
#  ------------------------
# Query Item:
#   title           [구운 통밀 고로케 3개입 세트] 야채 고로케, 비건 간식, 식사대용, 구운 통밀 고로케
# purchase_url    https://smartstore.naver.com/thebreadblue/prod...
# Name: 19, dtype: object
# Recommendation Items:
#                                        title  \
# 121  [구운 통밀 고로케 6개입 세트] 야채 고로케, 비건 간식, 식사대용
#
#                                           purchase_url
# 121  https://smartstore.naver.com/thebreadblue/prod...
#  ------------------------
# Query Item:
#   title                              비건이레 비건 티케이크 비건빵 글루텐프리 단호박티케이크
# purchase_url    https://smartstore.naver.com/vegan_for_sevenda...
# Name: 20, dtype: object
# Recommendation Items:
#                               title  \
# 47  비건이레 비건빵 글루텐프리 홀파운드케이크 쑥무화과파운드
#
#                                          purchase_url
# 47  https://smartstore.naver.com/vegan_for_sevenda...
#  ------------------------
# Query Item:
#   title                        틴베이크 플틴쿠키 저당 고단백 프로틴 단백질 월넛오리지널 쿠키 빵
# purchase_url    https://smartstore.naver.com/teinbake/products...
# Name: 21, dtype: object
# Recommendation Items:
#  Empty DataFrame
# Columns: [title, purchase_url]
# Index: []
#  ------------------------
# Query Item:
#   title                            글루텐프리 다이어트빵 쌀디저트 쌀마들렌 2개세트 할인 비건
# purchase_url    https://smartstore.naver.com/earth-born/produc...
# Name: 22, dtype: object
# Recommendation Items:
#                                                  title  \
# 151  글루텐프리 다이어트빵 쌀디저트 찹쌀휘낭시에 2개 세트 비건 구움과자 선물 바닐라 카카오
#
#                                           purchase_url
# 151  https://smartstore.naver.com/earth-born/produc...
#  ------------------------
# Query Item:
#   title            [모닐이네하우스] 특허받은 레시피로 만든 무설탕, 노밀가루, 노생크림 갸또쇼콜라 시리즈
# purchase_url    https://smartstore.naver.com/monil2house/produ...
# Name: 23, dtype: object
# Recommendation Items:
#  Empty DataFrame
# Columns: [title, purchase_url]
# Index: []
#  ------------------------
# Query Item:
#   title              굿다운 1/9저칼로리 저당 딸기잼 1kg 리필팩, 당뇨키토몰입점 스테비아잼 굿다운잼
# purchase_url    https://smartstore.naver.com/grimmsbread/produ...
# Name: 24, dtype: object
# Recommendation Items:
#                                                   title  \
# 9    굿다운 1/9 저칼로리 저당 치아딸기잼, 서울어워드수상 당뇨와건강몰입점 스테비아잼 ...
# 68   (1병+1병) 그림의빵 굿다운 1/9 저칼로리 저당 치아딸기잼, 서울어워드수상 당뇨...
# 182                                     굿다운 저당 초코잼, 1병
#
#                                           purchase_url
# 9    https://smartstore.naver.com/grimmsbread/produ...
# 68   https://smartstore.naver.com/grimmsbread/produ...
# 182  https://smartstore.naver.com/grimmsbread/produ...
#  ------------------------
# Query Item:
#   title               그림의빵 완벽저당 전제품 맛보기 10개 세트(1/9딸기잼 포함), 당뇨와건강몰입점
# purchase_url    https://smartstore.naver.com/grimmsbread/produ...
# Name: 25, dtype: object
# Recommendation Items:
#                                                   title  \
# 68   (1병+1병) 그림의빵 굿다운 1/9 저칼로리 저당 치아딸기잼, 서울어워드수상 당뇨...
# 168  그림의빵 저당빵 베스트셀러 달콤세트 10개(크림빵3종+휘낭시에2종), 각2개씩 당뇨...
#
#                                           purchase_url
# 68   https://smartstore.naver.com/grimmsbread/produ...
# 168  https://smartstore.naver.com/grimmsbread/produ...
#  ------------------------
# Query Item:
#   title                                           비건 글루텐프리 베이글 [호박]
# purchase_url    https://smartstore.naver.com/dearmyqueen1553/p...
# Name: 26, dtype: object
# Recommendation Items:
#                                  title  \
# 135                  비건 글루텐프리 베이글 [쑥]
# 35                 비건 글루텐프리 베이글 [기본맛]
# 0    냥빵 파운드 저탄수 대체당 제로 빵 글루텐프리 건강빵 비건
#
#                                           purchase_url
# 135  https://smartstore.naver.com/dearmyqueen1553/p...
# 35   https://smartstore.naver.com/dearmyqueen1553/p...
# 0    https://smartstore.naver.com/nyangppang/produc...
#  ------------------------
# Query Item:
#   title                                비건 유기농 쌀 노오일 휘낭시에 드낭시에 글루텐프리
# purchase_url    https://smartstore.naver.com/meandri/products/...
# Name: 27, dtype: object
# Recommendation Items:
#  Empty DataFrame
# Columns: [title, purchase_url]
# Index: []
#  ------------------------
# Query Item:
#   title                                현미 카스테라 비건빵 글루텐프리 쌀빵 디저트 건강빵
# purchase_url    https://smartstore.naver.com/thebreadblue/prod...
# Name: 28, dtype: object
# Recommendation Items:
#                                            title  \
# 5          [쌀낭시에 5종x2개입] 비건빵 글루텐프리 쌀빵 휘낭시에 건강간식
# 135                            비건 글루텐프리 베이글 [쑥]
# 36   [동호가 만든 현미빵] 더브레드블루 비건빵 쌀빵 건강간식 저당 건강 식사대용
#
#                                           purchase_url
# 5    https://smartstore.naver.com/thebreadblue/prod...
# 135  https://smartstore.naver.com/dearmyqueen1553/p...
# 36   https://smartstore.naver.com/thebreadblue/prod...
#  ------------------------
# Query Item:
#   title                                  무설탕 비건베이커리 디저트 빵 간식 흑임자 쿠키
# purchase_url    https://smartstore.naver.com/veganez/products/...
# Name: 29, dtype: object
# Recommendation Items:
#                                         title  \
# 150                 저당간식 비건베이커리 글루텐프리 아몬드 쿠키
# 6    꾸디 이달의 비건디저트 (비건쿠키 비건빵 베이커리 웨딩임페리얼 무화과)
#
#                                           purchase_url
# 150  https://smartstore.naver.com/veganez/products/...
# 6    https://smartstore.naver.com/ggudi/products/65...
#  ------------------------
# Query Item:
#   title                                       비건쿠키 글루텐프리 쌀 수제 건강 간식
# purchase_url    https://smartstore.naver.com/chopcookie/produc...
# Name: 30, dtype: object
# Recommendation Items:
#  Empty DataFrame
# Columns: [title, purchase_url]
# Index: []
#  ------------------------
# Query Item:
#   title                           [모닐이네하우스] 수제 쌀 르뱅 쿠키 시리즈 9종 글루텐프리
# purchase_url    https://smartstore.naver.com/monil2house/produ...
# Name: 31, dtype: object
# Recommendation Items:
#                          title  \
# 141  키토빵앗간 쿠키 (저당 글루텐프리 저탄수빵)
#
#                                           purchase_url
# 141  https://smartstore.naver.com/ketobbang/product...
#  ------------------------
# Query Item:
#   title                레몬 키토 머핀 저탄고지 냥빵 저탄수 빵 저당안심 식사대용 빵 무설탕 비건 키토
# purchase_url    https://smartstore.naver.com/nyangppang/produc...
# Name: 32, dtype: object
# Recommendation Items:
#  Empty DataFrame
# Columns: [title, purchase_url]
# Index: []
#  ------------------------
# Query Item:
#   title                                           비건 쌀 마들렌 - 초코칩 초코
# purchase_url    https://smartstore.naver.com/dearmyqueen1553/p...
# Name: 33, dtype: object
# Recommendation Items:
#                     title                                       purchase_url
# 56    비건 쌀 마들렌 - 아마레또 커피  https://smartstore.naver.com/dearmyqueen1553/p...
# 190  비건 쌀 마들렌 - 콩고물 범벅 쑥  https://smartstore.naver.com/dearmyqueen1553/p...
# 124             비건버터 쌀식빵  https://smartstore.naver.com/dearmyqueen1553/p...
#  ------------------------
# Query Item:
#   title                                비건케이크 비건 티라미수 떠먹는 쌀케이크 글루텐프리
# purchase_url    https://smartstore.naver.com/vegandaum/product...
# Name: 34, dtype: object
# Recommendation Items:
#  Empty DataFrame
# Columns: [title, purchase_url]
# Index: []
#  ------------------------
# Query Item:
#   title                                          비건 글루텐프리 베이글 [기본맛]
# purchase_url    https://smartstore.naver.com/dearmyqueen1553/p...
# Name: 35, dtype: object
# Recommendation Items:
#                                  title  \
# 135                  비건 글루텐프리 베이글 [쑥]
# 26                  비건 글루텐프리 베이글 [호박]
# 0    냥빵 파운드 저탄수 대체당 제로 빵 글루텐프리 건강빵 비건
#
#                                           purchase_url
# 135  https://smartstore.naver.com/dearmyqueen1553/p...
# 26   https://smartstore.naver.com/dearmyqueen1553/p...
# 0    https://smartstore.naver.com/nyangppang/produc...
#  ------------------------
# Query Item:
#   title                  [동호가 만든 현미빵] 더브레드블루 비건빵 쌀빵 건강간식 저당 건강 식사대용
# purchase_url    https://smartstore.naver.com/thebreadblue/prod...
# Name: 36, dtype: object
# Recommendation Items:
#                                      title  \
# 76   [프랑스 바게트] 더브레드블루 비건빵 건강간식 저당 건강 식사대용
# 114   [호두 깜빠뉴] 더브레드블루 비건빵 건강간식 저당 건강 식사대용
# 127    [호밀100] 더브레드블루 비건빵 건강간식 저당 건강 식사대용
#
#                                           purchase_url
# 76   https://smartstore.naver.com/thebreadblue/prod...
# 114  https://smartstore.naver.com/thebreadblue/prod...
# 127  https://smartstore.naver.com/thebreadblue/prod...
#  ------------------------
# Query Item:
#   title                  [더브레드블루 저당 통밀식빵] 당1g 다이어트 샌드위치 식단 노계란 비건식빵
# purchase_url    https://smartstore.naver.com/thebreadblue/prod...
# Name: 37, dtype: object
# Recommendation Items:
#  Empty DataFrame
# Columns: [title, purchase_url]
# Index: []
#  ------------------------
# Query Item:
#   title                        [모닐이네하우스] 치즈 여왕 노밀가루 바스크 치즈케이크 글루텐프리
# purchase_url    https://smartstore.naver.com/monil2house/produ...
# Name: 38, dtype: object
# Recommendation Items:
#  Empty DataFrame
# Columns: [title, purchase_url]
# Index: []
#  ------------------------
# Query Item:
#   title                [모닐이네하우스] No밀가루, 글루텐프리 수제 큐브 쌀 파운드 (2개씩) 시리즈
# purchase_url    https://smartstore.naver.com/monil2house/produ...
# Name: 39, dtype: object
# Recommendation Items:
#                                   title  \
# 53  [모닐이네하우스] 수제 쌀 스콘 시리즈 글루텐프리, NO 에그
#
#                                          purchase_url
# 53  https://smartstore.naver.com/monil2house/produ...
#  ------------------------
# Query Item:
#   title                                              우주 크림빵(초코, 밀크)
# purchase_url    https://smartstore.naver.com/dduddustore/produ...
# Name: 40, dtype: object
# Recommendation Items:
#                      title                                       purchase_url
# 111  우주 크림빵[밀크, 초코][10개입]  https://smartstore.naver.com/dduddustore/produ...
#  ------------------------
# Query Item:
#   title           저당모닝빵4팩+저당딸기잼 1kg 리필팩 세트구성, 저칼로리잼, 100%곡물단백질, ...
# purchase_url    https://smartstore.naver.com/grimmsbread/produ...
# Name: 41, dtype: object
# Recommendation Items:
#                                                   title  \
# 193  (3팩+3팩) 그림의빵 모닝빵 총 6팩, 저당식단용빵 100%곡물단백질 당뇨와건강몰...
# 197  그림의빵 코코모닝빵 3팩, 저당식단용빵 100%곡물단백질 당뇨와건강몰입점 노밀가루 ...
#
#                                           purchase_url
# 193  https://smartstore.naver.com/grimmsbread/produ...
# 197  https://smartstore.naver.com/grimmsbread/produ...
#  ------------------------
# Query Item:
#   title                                카카오 큐브 대체당 냥빵 글루텐프리 대체당 노밀가루
# purchase_url    https://smartstore.naver.com/nyangppang/produc...
# Name: 42, dtype: object
# Recommendation Items:
#                                  title  \
# 0    냥빵 파운드 저탄수 대체당 제로 빵 글루텐프리 건강빵 비건
# 135                  비건 글루텐프리 베이글 [쑥]
# 26                  비건 글루텐프리 베이글 [호박]
#
#                                           purchase_url
# 0    https://smartstore.naver.com/nyangppang/produc...
# 135  https://smartstore.naver.com/dearmyqueen1553/p...
# 26   https://smartstore.naver.com/dearmyqueen1553/p...
#  ------------------------
# Query Item:
#   title                      프로틴빵 노밀가루 글루텐프리 식단관리 단백질빵 당조절 식사빵 카스테라
# purchase_url    https://smartstore.naver.com/6-bbang/products/...
# Name: 43, dtype: object
# Recommendation Items:
#  Empty DataFrame
# Columns: [title, purchase_url]
# Index: []
#  ------------------------
# Query Item:
#   title                                 클래식 소보로빵 비건빵 100% 건강빵 영양 간식
# purchase_url    https://smartstore.naver.com/thebreadblue/prod...
# Name: 44, dtype: object
# Recommendation Items:
#                                           title  \
# 91           클래식 단팥빵 비건빵 100% 건강빵 영양 간식 더브레드블루
# 46   [클래식 단팥빵 5개 세트] 비건빵 100% 건강빵 영양 간식 더브레드블루
# 138                    소소한 소금빵 비건빵 100% 건강빵 간식
#
#                                           purchase_url
# 91   https://smartstore.naver.com/thebreadblue/prod...
# 46   https://smartstore.naver.com/thebreadblue/prod...
# 138  https://smartstore.naver.com/thebreadblue/prod...
#  ------------------------
# Query Item:
#   title                         매주 목요일 2pm 오픈 비건쿠키 노오일 글루텐프리 두부크림치즈
# purchase_url    https://smartstore.naver.com/splashbakery/prod...
# Name: 45, dtype: object
# Recommendation Items:
#  Empty DataFrame
# Columns: [title, purchase_url]
# Index: []
#  ------------------------
# Query Item:
#   title                   [클래식 단팥빵 5개 세트] 비건빵 100% 건강빵 영양 간식 더브레드블루
# purchase_url    https://smartstore.naver.com/thebreadblue/prod...
# Name: 46, dtype: object
# Recommendation Items:
#                                         title  \
# 91         클래식 단팥빵 비건빵 100% 건강빵 영양 간식 더브레드블루
# 44               클래식 소보로빵 비건빵 100% 건강빵 영양 간식
# 48  [더브레드블루 간식빵 6종 맛보기 세트] 비건빵 100% 건강빵 생일선물
#
#                                          purchase_url
# 91  https://smartstore.naver.com/thebreadblue/prod...
# 44  https://smartstore.naver.com/thebreadblue/prod...
# 48  https://smartstore.naver.com/thebreadblue/prod...
#  ------------------------
# Query Item:
#   title                              비건이레 비건빵 글루텐프리 홀파운드케이크 쑥무화과파운드
# purchase_url    https://smartstore.naver.com/vegan_for_sevenda...
# Name: 47, dtype: object
# Recommendation Items:
#                                title  \
# 20   비건이레 비건 티케이크 비건빵 글루텐프리 단호박티케이크
# 176                     메종드비건파운드케이크
#
#                                           purchase_url
# 20   https://smartstore.naver.com/vegan_for_sevenda...
# 176  https://smartstore.naver.com/maison_de_vegan/p...
#  ------------------------
# Query Item:
#   title                    [더브레드블루 간식빵 6종 맛보기 세트] 비건빵 100% 건강빵 생일선물
# purchase_url    https://smartstore.naver.com/thebreadblue/prod...
# Name: 48, dtype: object
# Recommendation Items:
#                                           title  \
# 46   [클래식 단팥빵 5개 세트] 비건빵 100% 건강빵 영양 간식 더브레드블루
# 91           클래식 단팥빵 비건빵 100% 건강빵 영양 간식 더브레드블루
# 113           [소소한 소금빵 10개 세트] 비건빵 100% 건강빵 간식
#
#                                           purchase_url
# 46   https://smartstore.naver.com/thebreadblue/prod...
# 91   https://smartstore.naver.com/thebreadblue/prod...
# 113  https://smartstore.naver.com/thebreadblue/prod...
#  ------------------------
# Query Item:
#   title                         틴베이크 플틴스콘 수제 고단백 프로틴 통밀빵 단백질 플레인 스콘
# purchase_url    https://smartstore.naver.com/teinbake/products...
# Name: 49, dtype: object
# Recommendation Items:
#  Empty DataFrame
# Columns: [title, purchase_url]
# Index: []
#  ------------------------
# Query Item:
#   title                                                    두부 쌀 베이글
# purchase_url    https://smartstore.naver.com/earth-born/produc...
# Name: 50, dtype: object
# Recommendation Items:
#  Empty DataFrame
# Columns: [title, purchase_url]
# Index: []
#  ------------------------
# Query Item:
#   title                            비건 이지 뉴초콜렛칩 쿠키 노밀가루 쌀 글루텐프리 비건쿠키
# purchase_url    https://smartstore.naver.com/veganez/products/...
# Name: 51, dtype: object
# Recommendation Items:
#                            title  \
# 195   초콜렛칩 쿠키 노밀가루 쌀 글루텐프리 비건쿠키
# 17    레몬 얼그레이 수제쿠키 쌀 글루텐프리 비건쿠키
# 85   얼그레이 초코볼 볼쿠키 비건쿠키 저당 글루텐프리
#
#                                           purchase_url
# 195  https://smartstore.naver.com/veganez/products/...
# 17   https://smartstore.naver.com/veganez/products/...
# 85   https://smartstore.naver.com/veganez/products/...
#  ------------------------
# Query Item:
#   title                        당류 0g 저당 마들렌 무설탕 무밀가루 고식이섬유 식단 간식 디저
# purchase_url    https://smartstore.naver.com/ketopantry/produc...
# Name: 52, dtype: object
# Recommendation Items:
#  Empty DataFrame
# Columns: [title, purchase_url]
# Index: []
#  ------------------------
# Query Item:
#   title                          [모닐이네하우스] 수제 쌀 스콘 시리즈 글루텐프리, NO 에그
# purchase_url    https://smartstore.naver.com/monil2house/produ...
# Name: 53, dtype: object
# Recommendation Items:
#                                             title  \
# 39  [모닐이네하우스] No밀가루, 글루텐프리 수제 큐브 쌀 파운드 (2개씩) 시리즈
#
#                                          purchase_url
# 39  https://smartstore.naver.com/monil2house/produ...
#  ------------------------
# Query Item:
#   title              [포포브레드] 비건 비스코티 초코 아몬드 / 쌀 디저트 글루텐프리 노밀가루 베이커리
# purchase_url    https://smartstore.naver.com/forfourbread/prod...
# Name: 54, dtype: object
# Recommendation Items:
#                                             title  \
# 89    [포포브레드] 비건 버터바 호지차 / 쌀 디저트 글루텐프리 노밀가루 베이커리
# 100     [포포브레드] 스콘 3종 / 쌀 디저트 글루텐프리 노밀가루 비건 베이커리
# 60   [포포브레드] 애플베리 크럼블 / 쌀 디저트 글루텐프리 노밀가루 비건 베이커리
#
#                                           purchase_url
# 89   https://smartstore.naver.com/forfourbread/prod...
# 100  https://smartstore.naver.com/forfourbread/prod...
# 60   https://smartstore.naver.com/forfourbread/prod...
#  ------------------------
# Query Item:
#   title                          비건 유기농 쌀 프로틴 쿠콘 4종 (쿠키 + 스콘) 글루텐프리
# purchase_url    https://smartstore.naver.com/meandri/products/...
# Name: 55, dtype: object
# Recommendation Items:
#  Empty DataFrame
# Columns: [title, purchase_url]
# Index: []
#  ------------------------
# Query Item:
#   title                                          비건 쌀 마들렌 - 아마레또 커피
# purchase_url    https://smartstore.naver.com/dearmyqueen1553/p...
# Name: 56, dtype: object
# Recommendation Items:
#                     title                                       purchase_url
# 33     비건 쌀 마들렌 - 초코칩 초코  https://smartstore.naver.com/dearmyqueen1553/p...
# 190  비건 쌀 마들렌 - 콩고물 범벅 쑥  https://smartstore.naver.com/dearmyqueen1553/p...
# 124             비건버터 쌀식빵  https://smartstore.naver.com/dearmyqueen1553/p...
#  ------------------------
# Query Item:
#   title                                                     메종드비건스콘
# purchase_url    https://smartstore.naver.com/maison_de_vegan/p...
# Name: 57, dtype: object
# Recommendation Items:
#  Empty DataFrame
# Columns: [title, purchase_url]
# Index: []
#  ------------------------
# Query Item:
#   title                         로투스 비스코프 비건케이크 더브레드블루 (No 계란 우유 버터)
# purchase_url    https://smartstore.naver.com/thebreadblue/prod...
# Name: 58, dtype: object
# Recommendation Items:
#                                                  title  \
# 83     [더브레드블루 벨기에 초콜릿 비건케이크 1호] 생일 케이크 디저트(No우유계란버터)
# 107  [더브레드블루 생크림 비건케이크 1호] 순식물성 생일 케이크 디저트(No 우유계란버터)
# 124                                          비건버터 쌀식빵
#
#                                           purchase_url
# 83   https://smartstore.naver.com/thebreadblue/prod...
# 107  https://smartstore.naver.com/thebreadblue/prod...
# 124  https://smartstore.naver.com/dearmyqueen1553/p...
#  ------------------------
# Query Item:
#   title                    저당 건강 간식 시나몬두 아몬드 호두 하루 견과류 쿠키 글루텐프리 디저트
# purchase_url    https://smartstore.naver.com/veganez/products/...
# Name: 59, dtype: object
# Recommendation Items:
#                              title  \
# 150      저당간식 비건베이커리 글루텐프리 아몬드 쿠키
# 139        저당 비건 글루텐프리 간식 피넛버터 쿠키
# 143  땅콩이 피칸 볼 쿠키 비건쿠키 글루텐프리 저당 간식
#
#                                           purchase_url
# 150  https://smartstore.naver.com/veganez/products/...
# 139  https://smartstore.naver.com/veganez/products/...
# 143  https://smartstore.naver.com/veganez/products/...
#  ------------------------
# Query Item:
#   title                 [포포브레드] 애플베리 크럼블 / 쌀 디저트 글루텐프리 노밀가루 비건 베이커리
# purchase_url    https://smartstore.naver.com/forfourbread/prod...
# Name: 60, dtype: object
# Recommendation Items:
#                                            title  \
# 89   [포포브레드] 비건 버터바 호지차 / 쌀 디저트 글루텐프리 노밀가루 베이커리
# 100    [포포브레드] 스콘 3종 / 쌀 디저트 글루텐프리 노밀가루 비건 베이커리
# 130  [포포브레드] 조각 호두파이 / 쌀 디저트 글루텐프리 노밀가루 비건 베이커리
#
#                                           purchase_url
# 89   https://smartstore.naver.com/forfourbread/prod...
# 100  https://smartstore.naver.com/forfourbread/prod...
# 130  https://smartstore.naver.com/forfourbread/prod...
#  ------------------------
# Query Item:
#   title                                              미니 발로나 초코 브라우니
# purchase_url    https://smartstore.naver.com/dearmyqueen1553/p...
# Name: 61, dtype: object
# Recommendation Items:
#                  title                                       purchase_url
# 33  비건 쌀 마들렌 - 초코칩 초코  https://smartstore.naver.com/dearmyqueen1553/p...
#  ------------------------
# Query Item:
#   title              [모닐이네하우스] 특허받은 레시피, 콩으로 만든 무설탕 노생크림 키쇼(키토 쇼콜라)
# purchase_url    https://smartstore.naver.com/monil2house/produ...
# Name: 62, dtype: object
# Recommendation Items:
#                                                 title  \
# 94  [모닐이네하우스] 특허 레시피로 만든 무설탕, 글루텐프리 2단 초콜릿 케이크 DIY키트
#
#                                          purchase_url
# 94  https://smartstore.naver.com/monil2house/produ...
#  ------------------------
# Query Item:
#   title                                      노밀가루 국산 쌀가루 글루텐프리 휘낭시에
# purchase_url    https://smartstore.naver.com/b__ethel/products...
# Name: 63, dtype: object
# Recommendation Items:
#  Empty DataFrame
# Columns: [title, purchase_url]
# Index: []
#  ------------------------
# Query Item:
#   title                           비건 유기농 쌀 & 완두단백 & 제로슈가 프로틴볼 글루텐프리
# purchase_url    https://smartstore.naver.com/meandri/products/...
# Name: 64, dtype: object
# Recommendation Items:
#                                 title  \
# 18  비건 유기농 쌀 제로슈가 고구마브라우니 미앤드리 글루텐프리
#
#                                          purchase_url
# 18  https://smartstore.naver.com/meandri/products/...
#  ------------------------
# Query Item:
#   title               [통밀식빵2개+아침한톨 땅콩초코맛 스프레드1개 세트 ] 땅콩잼 더브레드블루X푸로운
# purchase_url    https://smartstore.naver.com/thebreadblue/prod...
# Name: 65, dtype: object
# Recommendation Items:
#                                               title  \
# 95  [치아바타 3종+아침한톨 땅콩초코맛 스프레드1개 세트 ] 땅콩잼 더브레드블루X푸로운
# 8       [발효종 순수 통밀빵 2개입 1세트] 저당빵 비건 건강 식사대용 더브레드블루
#
#                                          purchase_url
# 95  https://smartstore.naver.com/thebreadblue/prod...
# 8   https://smartstore.naver.com/thebreadblue/prod...
#  ------------------------
# Query Item:
#   title                                               메종드비건 홀파운드케이크
# purchase_url    https://smartstore.naver.com/maison_de_vegan/p...
# Name: 66, dtype: object
# Recommendation Items:
#             title                                       purchase_url
# 176  메종드비건파운드케이크  https://smartstore.naver.com/maison_de_vegan/p...
# 156    메종드비건 마들렌  https://smartstore.naver.com/maison_de_vegan/p...
# 80      메종드비건 머핀  https://smartstore.naver.com/maison_de_vegan/p...
#  ------------------------
# Query Item:
#   title           프로넛 프로틴 오븐에 구운 도넛 카카오 밀가루없는 단백질 빵 식사대용 건강한 간식 ...
# purchase_url    https://smartstore.naver.com/pronut/products/5...
# Name: 67, dtype: object
# Recommendation Items:
#                                                   title  \
# 192  [box] 프로넛 프로틴 도넛 카카오 밀가루없는 단백질 빵 식사대용 건강한 간식 글...
#
#                                           purchase_url
# 192  https://smartstore.naver.com/pronut/products/7...
#  ------------------------
# Query Item:
#   title           (1병+1병) 그림의빵 굿다운 1/9 저칼로리 저당 치아딸기잼, 서울어워드수상 당뇨...
# purchase_url    https://smartstore.naver.com/grimmsbread/produ...
# Name: 68, dtype: object
# Recommendation Items:
#                                                  title  \
# 9   굿다운 1/9 저칼로리 저당 치아딸기잼, 서울어워드수상 당뇨와건강몰입점 스테비아잼 ...
# 24     굿다운 1/9저칼로리 저당 딸기잼 1kg 리필팩, 당뇨키토몰입점 스테비아잼 굿다운잼
# 25      그림의빵 완벽저당 전제품 맛보기 10개 세트(1/9딸기잼 포함), 당뇨와건강몰입점
#
#                                          purchase_url
# 9   https://smartstore.naver.com/grimmsbread/produ...
# 24  https://smartstore.naver.com/grimmsbread/produ...
# 25  https://smartstore.naver.com/grimmsbread/produ...
#  ------------------------
# Query Item:
#   title                                  노밀가루 프로틴 식빵 식단조절빵 식사빵 큐브식빵
# purchase_url    https://smartstore.naver.com/6-bbang/products/...
# Name: 69, dtype: object
# Recommendation Items:
#  Empty DataFrame
# Columns: [title, purchase_url]
# Index: []
#  ------------------------
# Query Item:
#   title                   [모닐이네하우스] 수능 시험 합격 기원 쌀 디저트 특별 종합 선물세트 응원
# purchase_url    https://smartstore.naver.com/monil2house/produ...
# Name: 70, dtype: object
# Recommendation Items:
#  Empty DataFrame
# Columns: [title, purchase_url]
# Index: []
#  ------------------------
# Query Item:
#   title                          플레인 프프쿠키 프로틴빵 고단백 수제 글루텐프리 non-gmo
# purchase_url    https://smartstore.naver.com/f_nergy/products/...
# Name: 71, dtype: object
# Recommendation Items:
#                                             title  \
# 200  초콩머핀 초코 프로틴빵 고단백 수제 글루텐프리 병아리콩 non-gmo 골라담기
# 109            네플스콘 프로틴빵 플레인 고단백 수제 글루텐프리스콘 골라담기
#
#                                           purchase_url
# 200  https://smartstore.naver.com/f_nergy/products/...
# 109  https://smartstore.naver.com/f_nergy/products/...
#  ------------------------
# Query Item:
#   title                                           초코 부에노 저당 간식 비건쿠키
# purchase_url    https://smartstore.naver.com/veganez/products/...
# Name: 72, dtype: object
# Recommendation Items:
#                                  title  \
# 188     비건이지 저당 쿠키 건강 간식 아몬드 초코칩 비건쿠키
# 140              저당 간식 쿠키 피넛 초코칩 땅콩쿠키
# 162  저당 수제 간식 얼그레이 초코칩 글루텐프리 홍차 비건 쿠키
#
#                                           purchase_url
# 188  https://smartstore.naver.com/veganez/products/...
# 140  https://smartstore.naver.com/veganez/products/...
# 162  https://smartstore.naver.com/veganez/products/...
#  ------------------------
# Query Item:
#   title                           무설탕 프로틴 수제 키토 그래놀라 4종 270g 당일 로스팅
# purchase_url    https://smartstore.naver.com/ketopantry/produc...
# Name: 73, dtype: object
# Recommendation Items:
#  Empty DataFrame
# Columns: [title, purchase_url]
# Index: []
#  ------------------------
# Query Item:
#   title                                   무설탕 비건이지 현미 쌀 크런치 크럼블 크럼볼
# purchase_url    https://smartstore.naver.com/veganez/products/...
# Name: 74, dtype: object
# Recommendation Items:
#                                    title  \
# 178  무설탕 비건이지 먹어 볼 쿠키 플레인 쌀 크럼블 크럼볼 노슈가
# 186      크럼블 크럼볼 흑임자 아몬드 무설탕 비건이지 임자몬드볼
#
#                                           purchase_url
# 178  https://smartstore.naver.com/veganez/products/...
# 186  https://smartstore.naver.com/veganez/products/...
#  ------------------------
# Query Item:
#   title                      [달콤 통밀 크럼블] 더브레드블루 비건빵 건강간식 통밀 건강 식사대용
# purchase_url    https://smartstore.naver.com/thebreadblue/prod...
# Name: 75, dtype: object
# Recommendation Items:
#                                      title  \
# 76   [프랑스 바게트] 더브레드블루 비건빵 건강간식 저당 건강 식사대용
# 114   [호두 깜빠뉴] 더브레드블루 비건빵 건강간식 저당 건강 식사대용
# 127    [호밀100] 더브레드블루 비건빵 건강간식 저당 건강 식사대용
#
#                                           purchase_url
# 76   https://smartstore.naver.com/thebreadblue/prod...
# 114  https://smartstore.naver.com/thebreadblue/prod...
# 127  https://smartstore.naver.com/thebreadblue/prod...
#  ------------------------
# Query Item:
#   title                        [프랑스 바게트] 더브레드블루 비건빵 건강간식 저당 건강 식사대용
# purchase_url    https://smartstore.naver.com/thebreadblue/prod...
# Name: 76, dtype: object
# Recommendation Items:
#                                         title  \
# 196  [무화과 듬뿍 바게트] 더브레드블루 비건빵 건강간식 저당 건강 식사대용
# 114      [호두 깜빠뉴] 더브레드블루 비건빵 건강간식 저당 건강 식사대용
# 127       [호밀100] 더브레드블루 비건빵 건강간식 저당 건강 식사대용
#
#                                           purchase_url
# 196  https://smartstore.naver.com/thebreadblue/prod...
# 114  https://smartstore.naver.com/thebreadblue/prod...
# 127  https://smartstore.naver.com/thebreadblue/prod...
#  ------------------------
# Query Item:
#   title                                          약과 쿠키 영양 간식 건강 디저트
# purchase_url    https://smartstore.naver.com/thebreadblue/prod...
# Name: 77, dtype: object
# Recommendation Items:
#                                          title  \
# 44                클래식 소보로빵 비건빵 100% 건강빵 영양 간식
# 91          클래식 단팥빵 비건빵 100% 건강빵 영양 간식 더브레드블루
# 46  [클래식 단팥빵 5개 세트] 비건빵 100% 건강빵 영양 간식 더브레드블루
#
#                                          purchase_url
# 44  https://smartstore.naver.com/thebreadblue/prod...
# 91  https://smartstore.naver.com/thebreadblue/prod...
# 46  https://smartstore.naver.com/thebreadblue/prod...
#  ------------------------
# Query Item:
#   title                            [매콤한 올리브 치아바타] 저당빵 비건 치아바타 샌드위치빵
# purchase_url    https://smartstore.naver.com/thebreadblue/prod...
# Name: 78, dtype: object
# Recommendation Items:
#                   title                                       purchase_url
# 120         올리브 쌀 치아바타  https://smartstore.naver.com/dearmyqueen1553/p...
# 33   비건 쌀 마들렌 - 초코칩 초코  https://smartstore.naver.com/dearmyqueen1553/p...
# 124           비건버터 쌀식빵  https://smartstore.naver.com/dearmyqueen1553/p...
#  ------------------------
# Query Item:
#   title                             프로틴 오트밀 초코칩쿠키 5개 식단조절 간식 무설탕 쿠키
# purchase_url    https://smartstore.naver.com/6-bbang/products/...
# Name: 79, dtype: object
# Recommendation Items:
#  Empty DataFrame
# Columns: [title, purchase_url]
# Index: []
#  ------------------------
# Query Item:
#   title                                                    메종드비건 머핀
# purchase_url    https://smartstore.naver.com/maison_de_vegan/p...
# Name: 80, dtype: object
# Recommendation Items:
#               title                                       purchase_url
# 176    메종드비건파운드케이크  https://smartstore.naver.com/maison_de_vegan/p...
# 66   메종드비건 홀파운드케이크  https://smartstore.naver.com/maison_de_vegan/p...
#  ------------------------
# Query Item:
#   title                     저당 단백질 식빵 플레인 당류 0.1g 무설탕, 무밀가루 식단빵 건강빵
# purchase_url    https://smartstore.naver.com/ketopantry/produc...
# Name: 81, dtype: object
# Recommendation Items:
#                                   title  \
# 117     저당 고단백질 햄치즈롤 무설탕, 무밀가루 식단빵 건강빵
# 173  당류 0g 저당 단백질 깜빠뉴 무설탕 무밀가루 비건 키토제닉
#
#                                           purchase_url
# 117  https://smartstore.naver.com/ketopantry/produc...
# 173  https://smartstore.naver.com/ketopantry/produc...
#  ------------------------
# Query Item:
#   title                          글루텐프리빵 저당간식 아몬드가루빵 카스테라 파운드 - 크림치즈
# purchase_url    https://smartstore.naver.com/humming_pound/pro...
# Name: 82, dtype: object
# Recommendation Items:
#  Empty DataFrame
# Columns: [title, purchase_url]
# Index: []
#  ------------------------
# Query Item:
#   title              [더브레드블루 벨기에 초콜릿 비건케이크 1호] 생일 케이크 디저트(No우유계란버터)
# purchase_url    https://smartstore.naver.com/thebreadblue/prod...
# Name: 83, dtype: object
# Recommendation Items:
#                                                  title  \
# 107  [더브레드블루 생크림 비건케이크 1호] 순식물성 생일 케이크 디저트(No 우유계란버터)
# 58                로투스 비스코프 비건케이크 더브레드블루 (No 계란 우유 버터)
#
#                                           purchase_url
# 107  https://smartstore.naver.com/thebreadblue/prod...
# 58   https://smartstore.naver.com/thebreadblue/prod...
#  ------------------------
# Query Item:
#   title                                   프로틴스콘 노밀가루 노설탕 식단조절 간식 스콘
# purchase_url    https://smartstore.naver.com/6-bbang/products/...
# Name: 84, dtype: object
# Recommendation Items:
#                                  title  \
# 201  프로틴도넛 프로틴 노밀가루 무설탕 단백질 식단조절 단백질빵
#
#                                           purchase_url
# 201  https://smartstore.naver.com/6-bbang/products/...
#  ------------------------
# Query Item:
#   title                                  얼그레이 초코볼 볼쿠키 비건쿠키 저당 글루텐프리
# purchase_url    https://smartstore.naver.com/veganez/products/...
# Name: 85, dtype: object
# Recommendation Items:
#                                  title  \
# 162  저당 수제 간식 얼그레이 초코칩 글루텐프리 홍차 비건 쿠키
# 17          레몬 얼그레이 수제쿠키 쌀 글루텐프리 비건쿠키
# 155           저당간식 크런치 초코볼 비건쿠키 글루텐프리
#
#                                           purchase_url
# 162  https://smartstore.naver.com/veganez/products/...
# 17   https://smartstore.naver.com/veganez/products/...
# 155  https://smartstore.naver.com/veganez/products/...
#  ------------------------
# Query Item:
#   title                                                  돌체 로미아스 쿠키
# purchase_url    https://smartstore.naver.com/dearmyqueen1553/p...
# Name: 86, dtype: object
# Recommendation Items:
#  Empty DataFrame
# Columns: [title, purchase_url]
# Index: []
#  ------------------------
# Query Item:
#   title                                                    메종드비건 큐브
# purchase_url    https://smartstore.naver.com/maison_de_vegan/p...
# Name: 87, dtype: object
# Recommendation Items:
#  Empty DataFrame
# Columns: [title, purchase_url]
# Index: []
#  ------------------------
# Query Item:
#   title                                            달롤 X 망넛이네 콜라보 행사
# purchase_url    https://smartstore.naver.com/mangnut2/products...
# Name: 88, dtype: object
# Recommendation Items:
#  Empty DataFrame
# Columns: [title, purchase_url]
# Index: []
#  ------------------------
# Query Item:
#   title                  [포포브레드] 비건 버터바 호지차 / 쌀 디저트 글루텐프리 노밀가루 베이커리
# purchase_url    https://smartstore.naver.com/forfourbread/prod...
# Name: 89, dtype: object
# Recommendation Items:
#                                             title  \
# 100     [포포브레드] 스콘 3종 / 쌀 디저트 글루텐프리 노밀가루 비건 베이커리
# 60   [포포브레드] 애플베리 크럼블 / 쌀 디저트 글루텐프리 노밀가루 비건 베이커리
# 130   [포포브레드] 조각 호두파이 / 쌀 디저트 글루텐프리 노밀가루 비건 베이커리
#
#                                           purchase_url
# 100  https://smartstore.naver.com/forfourbread/prod...
# 60   https://smartstore.naver.com/forfourbread/prod...
# 130  https://smartstore.naver.com/forfourbread/prod...
#  ------------------------
# Query Item:
#   title                            [모닐이네하우스] 가장 핫하다는 쫀득쫀득 버터바 글루텐프리
# purchase_url    https://smartstore.naver.com/monil2house/produ...
# Name: 90, dtype: object
# Recommendation Items:
#  Empty DataFrame
# Columns: [title, purchase_url]
# Index: []
#  ------------------------
# Query Item:
#   title                           클래식 단팥빵 비건빵 100% 건강빵 영양 간식 더브레드블루
# purchase_url    https://smartstore.naver.com/thebreadblue/prod...
# Name: 91, dtype: object
# Recommendation Items:
#                                          title  \
# 46  [클래식 단팥빵 5개 세트] 비건빵 100% 건강빵 영양 간식 더브레드블루
# 44                클래식 소보로빵 비건빵 100% 건강빵 영양 간식
# 48   [더브레드블루 간식빵 6종 맛보기 세트] 비건빵 100% 건강빵 생일선물
#
#                                          purchase_url
# 46  https://smartstore.naver.com/thebreadblue/prod...
# 44  https://smartstore.naver.com/thebreadblue/prod...
# 48  https://smartstore.naver.com/thebreadblue/prod...
#  ------------------------
# Query Item:
#   title                      [포포브레드] 쌀식빵 포식이 / 저염 비건 빵 노밀가루 빵집 베이커리
# purchase_url    https://smartstore.naver.com/forfourbread/prod...
# Name: 92, dtype: object
# Recommendation Items:
#                                          title  \
# 112  [포포브레드] 쌀 소금빵 치즈 / 시오빵 비건 노밀가루 빵 빵집 베이커리
#
#                                           purchase_url
# 112  https://smartstore.naver.com/forfourbread/prod...
#  ------------------------
# Query Item:
#   title                                      크런치 오트밀 무설탕 그래놀라 비건디저트
# purchase_url    https://smartstore.naver.com/veganez/products/...
# Name: 93, dtype: object
# Recommendation Items:
#  Empty DataFrame
# Columns: [title, purchase_url]
# Index: []
#  ------------------------
# Query Item:
#   title            [모닐이네하우스] 특허 레시피로 만든 무설탕, 글루텐프리 2단 초콜릿 케이크 DIY키트
# purchase_url    https://smartstore.naver.com/monil2house/produ...
# Name: 94, dtype: object
# Recommendation Items:
#                                                title  \
# 62   [모닐이네하우스] 특허받은 레시피, 콩으로 만든 무설탕 노생크림 키쇼(키토 쇼콜라)
# 202       [모닐이네하우스] 무설탕 3단 초콜릿 케이크 DIY키트 (연말파티, 행사)
#
#                                           purchase_url
# 62   https://smartstore.naver.com/monil2house/produ...
# 202  https://smartstore.naver.com/monil2house/produ...
#  ------------------------
# Query Item:
#   title              [치아바타 3종+아침한톨 땅콩초코맛 스프레드1개 세트 ] 땅콩잼 더브레드블루X푸로운
# purchase_url    https://smartstore.naver.com/thebreadblue/prod...
# Name: 95, dtype: object
# Recommendation Items:
#                                              title  \
# 65  [통밀식빵2개+아침한톨 땅콩초코맛 스프레드1개 세트 ] 땅콩잼 더브레드블루X푸로운
#
#                                          purchase_url
# 65  https://smartstore.naver.com/thebreadblue/prod...
#  ------------------------
# Query Item:
#   title            그림의빵 88kcal 저당 고단백 휘낭시에 12입, 당류0.3g 당뇨와건강몰입점 디저트
# purchase_url    https://smartstore.naver.com/grimmsbread/produ...
# Name: 96, dtype: object
# Recommendation Items:
#                                                 title  \
# 102   그림의빵 저당 고단백 라즈베리 초코 그낭시에 8입, 당뇨와건강몰입점 디저트 휘낭시에
# 177  그림의빵 저당 고단백 라즈베리 초코 그낭시에 16입, 당뇨와건강몰입점 디저트 휘낭시에
# 110             그림의빵 고단백 저당 크림빵 9개,100%곡물단백 당뇨와건강몰입점
#
#                                           purchase_url
# 102  https://smartstore.naver.com/grimmsbread/produ...
# 177  https://smartstore.naver.com/grimmsbread/produ...
# 110  https://smartstore.naver.com/grimmsbread/produ...
#  ------------------------
# Query Item:
#   title                     [밤식빵] 식사대용 비건 건강 통밤 소화잘되는 더브레드블루 (280g)
# purchase_url    https://smartstore.naver.com/thebreadblue/prod...
# Name: 97, dtype: object
# Recommendation Items:
#                                            title  \
# 8    [발효종 순수 통밀빵 2개입 1세트] 저당빵 비건 건강 식사대용 더브레드블루
# 187         [감자 치아바타] 저당빵, 비건빵, 건강빵 식사대용 더브레드블루
# 75       [달콤 통밀 크럼블] 더브레드블루 비건빵 건강간식 통밀 건강 식사대용
#
#                                           purchase_url
# 8    https://smartstore.naver.com/thebreadblue/prod...
# 187  https://smartstore.naver.com/thebreadblue/prod...
# 75   https://smartstore.naver.com/thebreadblue/prod...
#  ------------------------
# Query Item:
#   title                                비건베이커리 초당옥수수 수제쿠키 쌀빵 저당 비건쿠키
# purchase_url    https://smartstore.naver.com/veganez/products/...
# Name: 98, dtype: object
# Recommendation Items:
#  Empty DataFrame
# Columns: [title, purchase_url]
# Index: []
#  ------------------------
# Query Item:
#   title                                          💖 비건빵빵이네 빵 택배 마켓 💖
# purchase_url    https://smartstore.naver.com/bbang_vegan/produ...
# Name: 99, dtype: object
# Recommendation Items:
#  Empty DataFrame
# Columns: [title, purchase_url]
# Index: []
#  ------------------------
# Query Item:
#   title                    [포포브레드] 스콘 3종 / 쌀 디저트 글루텐프리 노밀가루 비건 베이커리
# purchase_url    https://smartstore.naver.com/forfourbread/prod...
# Name: 100, dtype: object
# Recommendation Items:
#                                             title  \
# 89    [포포브레드] 비건 버터바 호지차 / 쌀 디저트 글루텐프리 노밀가루 베이커리
# 60   [포포브레드] 애플베리 크럼블 / 쌀 디저트 글루텐프리 노밀가루 비건 베이커리
# 130   [포포브레드] 조각 호두파이 / 쌀 디저트 글루텐프리 노밀가루 비건 베이커리
#
#                                           purchase_url
# 89   https://smartstore.naver.com/forfourbread/prod...
# 60   https://smartstore.naver.com/forfourbread/prod...
# 130  https://smartstore.naver.com/forfourbread/prod...
#  ------------------------
# Query Item:
#   title                                순수 알룰로스 분말 100% 0Kcal 대체 감미료
# purchase_url    https://smartstore.naver.com/ketopantry/produc...
# Name: 101, dtype: object
# Recommendation Items:
#  Empty DataFrame
# Columns: [title, purchase_url]
# Index: []
#  ------------------------
# Query Item:
#   title              그림의빵 저당 고단백 라즈베리 초코 그낭시에 8입, 당뇨와건강몰입점 디저트 휘낭시에
# purchase_url    https://smartstore.naver.com/grimmsbread/produ...
# Name: 102, dtype: object
# Recommendation Items:
#                                                  title  \
# 177   그림의빵 저당 고단백 라즈베리 초코 그낭시에 16입, 당뇨와건강몰입점 디저트 휘낭시에
# 96   그림의빵 88kcal 저당 고단백 휘낭시에 12입, 당류0.3g 당뇨와건강몰입점 디저트
# 110              그림의빵 고단백 저당 크림빵 9개,100%곡물단백 당뇨와건강몰입점
#
#                                           purchase_url
# 177  https://smartstore.naver.com/grimmsbread/produ...
# 96   https://smartstore.naver.com/grimmsbread/produ...
# 110  https://smartstore.naver.com/grimmsbread/produ...
#  ------------------------
# Query Item:
#   title                              초코 브라우니 쿠키 비건디저트 꾸덕바 무설탕 글루텐프리
# purchase_url    https://smartstore.naver.com/vegandaum/product...
# Name: 103, dtype: object
# Recommendation Items:
#                            title  \
# 85   얼그레이 초코볼 볼쿠키 비건쿠키 저당 글루텐프리
# 155     저당간식 크런치 초코볼 비건쿠키 글루텐프리
#
#                                           purchase_url
# 85   https://smartstore.naver.com/veganez/products/...
# 155  https://smartstore.naver.com/veganez/products/...
#  ------------------------
# Query Item:
#   title             에이사 비건 버터 꾸덕바 버터바 글루텐프리 약과버터바 말차버터바 저오일 저당 저칼로리
# ...
# purchase_url    https://smartstore.naver.com/veganez/products/...
# Name: 178, dtype: object
# Recommendation Items:
#                                title  \
# 74        무설탕 비건이지 현미 쌀 크런치 크럼블 크럼볼
# 186  크럼블 크럼볼 흑임자 아몬드 무설탕 비건이지 임자몬드볼
#
#                                           purchase_url
# 74   https://smartstore.naver.com/veganez/products/...
# 186  https://smartstore.naver.com/veganez/products/...
#  ------------------------
# Query Item:
#   title                              키토빵앗간 디쉬 치즈 스콘 (저당 글루텐프리 저탄수빵)
# purchase_url    https://smartstore.naver.com/ketobbang/product...
# Name: 179, dtype: object
# Recommendation Items:
#                                 title  \
# 12    키토빵앗간 고메버터 파운드 (저당 글루텐프리 저탄수빵)
# 141         키토빵앗간 쿠키 (저당 글루텐프리 저탄수빵)
# 175  키토빵앗간 큐브 앙금 파운드 (저당 글루텐프리 저탄수빵)
#
#                                           purchase_url
# 12   https://smartstore.naver.com/ketobbang/product...
# 141  https://smartstore.naver.com/ketobbang/product...
# 175  https://smartstore.naver.com/ketobbang/product...
#  ------------------------
# Query Item:
#   title               [포포브레드] 파운드 3종 / 쌀 디저트 글루텐프리 케이크 노밀가루 비건 베이커리
# purchase_url    https://smartstore.naver.com/forfourbread/prod...
# Name: 180, dtype: object
# Recommendation Items:
#                                                 title  \
# 163  [포포브레드] 홀 파운드 3종 / 크리스마스 글루텐프리 케이크 노밀가루 비건 베이커리
# 89        [포포브레드] 비건 버터바 호지차 / 쌀 디저트 글루텐프리 노밀가루 베이커리
# 100         [포포브레드] 스콘 3종 / 쌀 디저트 글루텐프리 노밀가루 비건 베이커리
#
#                                           purchase_url
# 163  https://smartstore.naver.com/forfourbread/prod...
# 89   https://smartstore.naver.com/forfourbread/prod...
# 100  https://smartstore.naver.com/forfourbread/prod...
#  ------------------------
# Query Item:
#   title                          통밀빵 다이어트빵 스콘 비건 구움과자 스콘 3개 세트상품 선물
# purchase_url    https://smartstore.naver.com/earth-born/produc...
# Name: 181, dtype: object
# Recommendation Items:
#  Empty DataFrame
# Columns: [title, purchase_url]
# Index: []
#  ------------------------
# Query Item:
#   title                                              굿다운 저당 초코잼, 1병
# purchase_url    https://smartstore.naver.com/grimmsbread/produ...
# Name: 182, dtype: object
# Recommendation Items:
#                                                  title  \
# 9   굿다운 1/9 저칼로리 저당 치아딸기잼, 서울어워드수상 당뇨와건강몰입점 스테비아잼 ...
# 24     굿다운 1/9저칼로리 저당 딸기잼 1kg 리필팩, 당뇨키토몰입점 스테비아잼 굿다운잼
#
#                                          purchase_url
# 9   https://smartstore.naver.com/grimmsbread/produ...
# 24  https://smartstore.naver.com/grimmsbread/produ...
#  ------------------------
# Query Item:
#   title                            [비건 쿠키] 건강 간식, 영양 간식, 채식, 식물성 쿠키
# purchase_url    https://smartstore.naver.com/thebreadblue/prod...
# Name: 183, dtype: object
# Recommendation Items:
#  Empty DataFrame
# Columns: [title, purchase_url]
# Index: []
#  ------------------------
# Query Item:
#   title                                  저당 프로틴 스콘 무설탕 고댠백 수제 건강 간식
# purchase_url    https://smartstore.naver.com/ketopantry/produc...
# Name: 184, dtype: object
# Recommendation Items:
#  Empty DataFrame
# Columns: [title, purchase_url]
# Index: []
#  ------------------------
# Query Item:
#   title                                             구떼 비건 스모어 쿠키 4종
# purchase_url    https://smartstore.naver.com/gouterbakery/prod...
# Name: 185, dtype: object
# Recommendation Items:
#                       title                                       purchase_url
# 125  비건 글루텐 프리 마들렌 8종 (2P)  https://smartstore.naver.com/gouterbakery/prod...
#  ------------------------
# Query Item:
#   title                              크럼블 크럼볼 흑임자 아몬드 무설탕 비건이지 임자몬드볼
# purchase_url    https://smartstore.naver.com/veganez/products/...
# Name: 186, dtype: object
# Recommendation Items:
#                                    title  \
# 74            무설탕 비건이지 현미 쌀 크런치 크럼블 크럼볼
# 178  무설탕 비건이지 먹어 볼 쿠키 플레인 쌀 크럼블 크럼볼 노슈가
#
#                                           purchase_url
# 74   https://smartstore.naver.com/veganez/products/...
# 178  https://smartstore.naver.com/veganez/products/...
#  ------------------------
# Query Item:
#   title                         [감자 치아바타] 저당빵, 비건빵, 건강빵 식사대용 더브레드블루
# purchase_url    https://smartstore.naver.com/thebreadblue/prod...
# Name: 187, dtype: object
# Recommendation Items:
#                                        title  \
# 75   [달콤 통밀 크럼블] 더브레드블루 비건빵 건강간식 통밀 건강 식사대용
# 76     [프랑스 바게트] 더브레드블루 비건빵 건강간식 저당 건강 식사대용
# 114     [호두 깜빠뉴] 더브레드블루 비건빵 건강간식 저당 건강 식사대용
#
#                                           purchase_url
# 75   https://smartstore.naver.com/thebreadblue/prod...
# 76   https://smartstore.naver.com/thebreadblue/prod...
# 114  https://smartstore.naver.com/thebreadblue/prod...
#  ------------------------
# Query Item:
#   title                               비건이지 저당 쿠키 건강 간식 아몬드 초코칩 비건쿠키
# purchase_url    https://smartstore.naver.com/veganez/products/...
# Name: 188, dtype: object
# Recommendation Items:
#                                  title  \
# 72                  초코 부에노 저당 간식 비건쿠키
# 140              저당 간식 쿠키 피넛 초코칩 땅콩쿠키
# 162  저당 수제 간식 얼그레이 초코칩 글루텐프리 홍차 비건 쿠키
#
#                                           purchase_url
# 72   https://smartstore.naver.com/veganez/products/...
# 140  https://smartstore.naver.com/veganez/products/...
# 162  https://smartstore.naver.com/veganez/products/...
#  ------------------------
# Query Item:
#   title                           [모닐이네하우스] Best 100% 쌀 소금빵 (글루텐프리)
# purchase_url    https://smartstore.naver.com/monil2house/produ...
# Name: 189, dtype: object
# Recommendation Items:
#                                          title  \
# 10         [모닐이네하우스] 글루텐프리 100% 쌀 소금빵 5개 세트구성
# 152  [모닐이네하우스] 🌾 100% 글루텐프리 쌀로 만든 베이글 (비건/GF)
#
#                                           purchase_url
# 10   https://smartstore.naver.com/monil2house/produ...
# 152  https://smartstore.naver.com/monil2house/produ...
#  ------------------------
# Query Item:
#   title                                         비건 쌀 마들렌 - 콩고물 범벅 쑥
# purchase_url    https://smartstore.naver.com/dearmyqueen1553/p...
# Name: 190, dtype: object
# Recommendation Items:
#                    title                                       purchase_url
# 33    비건 쌀 마들렌 - 초코칩 초코  https://smartstore.naver.com/dearmyqueen1553/p...
# 56   비건 쌀 마들렌 - 아마레또 커피  https://smartstore.naver.com/dearmyqueen1553/p...
# 124            비건버터 쌀식빵  https://smartstore.naver.com/dearmyqueen1553/p...
#  ------------------------
# Query Item:
#   title                            글루텐프리 수제쿠키 저당 디저트맛집 마카다미아 쿠키-2개입
# purchase_url    https://smartstore.naver.com/humming_pound/pro...
# Name: 191, dtype: object
# Recommendation Items:
#                                  title  \
# 154    글루텐프리 휘낭시에 저당 디저트 휘낭시에맛집 - 2개입
# 162  저당 수제 간식 얼그레이 초코칩 글루텐프리 홍차 비건 쿠키
# 85         얼그레이 초코볼 볼쿠키 비건쿠키 저당 글루텐프리
#
#                                           purchase_url
# 154  https://smartstore.naver.com/humming_pound/pro...
# 162  https://smartstore.naver.com/veganez/products/...
# 85   https://smartstore.naver.com/veganez/products/...
#  ------------------------
# Query Item:
#   title           [box] 프로넛 프로틴 도넛 카카오 밀가루없는 단백질 빵 식사대용 건강한 간식 글...
# purchase_url    https://smartstore.naver.com/pronut/products/7...
# Name: 192, dtype: object
# Recommendation Items:
#                                                  title  \
# 67  프로넛 프로틴 오븐에 구운 도넛 카카오 밀가루없는 단백질 빵 식사대용 건강한 간식 ...
#
#                                          purchase_url
# 67  https://smartstore.naver.com/pronut/products/5...
#  ------------------------
# Query Item:
#   title           (3팩+3팩) 그림의빵 모닝빵 총 6팩, 저당식단용빵 100%곡물단백질 당뇨와건강몰...
# purchase_url    https://smartstore.naver.com/grimmsbread/produ...
# Name: 193, dtype: object
# Recommendation Items:
#                                                   title  \
# 197  그림의빵 코코모닝빵 3팩, 저당식단용빵 100%곡물단백질 당뇨와건강몰입점 노밀가루 ...
# 41   저당모닝빵4팩+저당딸기잼 1kg 리필팩 세트구성, 저칼로리잼, 100%곡물단백질, ...
# 110               그림의빵 고단백 저당 크림빵 9개,100%곡물단백 당뇨와건강몰입점
#
#                                           purchase_url
# 197  https://smartstore.naver.com/grimmsbread/produ...
# 41   https://smartstore.naver.com/grimmsbread/produ...
# 110  https://smartstore.naver.com/grimmsbread/produ...
#  ------------------------
# Query Item:
#   title                             에이사 비건 크림치즈쿠키 글루텐프리 저오일 저당 저칼로리
# purchase_url    https://smartstore.naver.com/asa_veganclass/pr...
# Name: 194, dtype: object
# Recommendation Items:
#                                                 title  \
# 104  에이사 비건 버터 꾸덕바 버터바 글루텐프리 약과버터바 말차버터바 저오일 저당 저칼로리
#
#                                           purchase_url
# 104  https://smartstore.naver.com/asa_veganclass/pr...
#  ------------------------
# Query Item:
#   title                                   초콜렛칩 쿠키 노밀가루 쌀 글루텐프리 비건쿠키
# purchase_url    https://smartstore.naver.com/veganez/products/...
# Name: 195, dtype: object
# Recommendation Items:
#                                 title  \
# 51  비건 이지 뉴초콜렛칩 쿠키 노밀가루 쌀 글루텐프리 비건쿠키
# 17         레몬 얼그레이 수제쿠키 쌀 글루텐프리 비건쿠키
# 85        얼그레이 초코볼 볼쿠키 비건쿠키 저당 글루텐프리
#
#                                          purchase_url
# 51  https://smartstore.naver.com/veganez/products/...
# 17  https://smartstore.naver.com/veganez/products/...
# 85  https://smartstore.naver.com/veganez/products/...
#  ------------------------
# Query Item:
#   title                     [무화과 듬뿍 바게트] 더브레드블루 비건빵 건강간식 저당 건강 식사대용
# purchase_url    https://smartstore.naver.com/thebreadblue/prod...
# Name: 196, dtype: object
# Recommendation Items:
#                                      title  \
# 76   [프랑스 바게트] 더브레드블루 비건빵 건강간식 저당 건강 식사대용
# 114   [호두 깜빠뉴] 더브레드블루 비건빵 건강간식 저당 건강 식사대용
# 127    [호밀100] 더브레드블루 비건빵 건강간식 저당 건강 식사대용
#
#                                           purchase_url
# 76   https://smartstore.naver.com/thebreadblue/prod...
# 114  https://smartstore.naver.com/thebreadblue/prod...
# 127  https://smartstore.naver.com/thebreadblue/prod...
#  ------------------------
# Query Item:
#   title           그림의빵 코코모닝빵 3팩, 저당식단용빵 100%곡물단백질 당뇨와건강몰입점 노밀가루 ...
# purchase_url    https://smartstore.naver.com/grimmsbread/produ...
# Name: 197, dtype: object
# Recommendation Items:
#                                                   title  \
# 193  (3팩+3팩) 그림의빵 모닝빵 총 6팩, 저당식단용빵 100%곡물단백질 당뇨와건강몰...
# 41   저당모닝빵4팩+저당딸기잼 1kg 리필팩 세트구성, 저칼로리잼, 100%곡물단백질, ...
# 110               그림의빵 고단백 저당 크림빵 9개,100%곡물단백 당뇨와건강몰입점
#
#                                           purchase_url
# 193  https://smartstore.naver.com/grimmsbread/produ...
# 41   https://smartstore.naver.com/grimmsbread/produ...
# 110  https://smartstore.naver.com/grimmsbread/produ...
#  ------------------------
# Query Item:
#   title                        [포포브레드] 쌀 치아바타 4종 / 빵 무설탕 저염 비건 베이커리
# purchase_url    https://smartstore.naver.com/forfourbread/prod...
# Name: 198, dtype: object
# Recommendation Items:
#  Empty DataFrame
# Columns: [title, purchase_url]
# Index: []
#  ------------------------
# Query Item:
#   title           프로넛 프로틴 큐브 파운드 밀가루없는 단백질 빵 에스프레소 식사대용 건강한 간식 글...
# purchase_url    https://smartstore.naver.com/pronut/products/6...
# Name: 199, dtype: object
# Recommendation Items:
#  Empty DataFrame
# Columns: [title, purchase_url]
# Index: []
#  ------------------------
# Query Item:
#   title                 초콩머핀 초코 프로틴빵 고단백 수제 글루텐프리 병아리콩 non-gmo 골라담기
# purchase_url    https://smartstore.naver.com/f_nergy/products/...
# Name: 200, dtype: object
# Recommendation Items:
#                                    title  \
# 71   플레인 프프쿠키 프로틴빵 고단백 수제 글루텐프리 non-gmo
# 109   네플스콘 프로틴빵 플레인 고단백 수제 글루텐프리스콘 골라담기
#
#                                           purchase_url
# 71   https://smartstore.naver.com/f_nergy/products/...
# 109  https://smartstore.naver.com/f_nergy/products/...
#  ------------------------
# Query Item:
#   title                            프로틴도넛 프로틴 노밀가루 무설탕 단백질 식단조절 단백질빵
# purchase_url    https://smartstore.naver.com/6-bbang/products/...
# Name: 201, dtype: object
# Recommendation Items:
#                                title  \
# 84        프로틴스콘 노밀가루 노설탕 식단조절 간식 스콘
# 117  저당 고단백질 햄치즈롤 무설탕, 무밀가루 식단빵 건강빵
#
#                                           purchase_url
# 84   https://smartstore.naver.com/6-bbang/products/...
# 117  https://smartstore.naver.com/ketopantry/produc...
#  ------------------------
# Query Item:
#   title                   [모닐이네하우스] 무설탕 3단 초콜릿 케이크 DIY키트 (연말파티, 행사)
# purchase_url    https://smartstore.naver.com/monil2house/produ...
# Name: 202, dtype: object
# Recommendation Items:
#                                                 title  \
# 94  [모닐이네하우스] 특허 레시피로 만든 무설탕, 글루텐프리 2단 초콜릿 케이크 DIY키트
#
#                                          purchase_url
# 94  https://smartstore.naver.com/monil2house/produ...
#  ------------------------
# Query Item:
#   title                                    두바이 초콜릿 쌀 비건쿠키 글루텐프리 빵택배
# purchase_url    https://smartstore.naver.com/vegandaum/product...
# Name: 203, dtype: object
# Recommendation Items:
#  Empty DataFrame
# Columns: [title, purchase_url]
# Index: []
#  ------------------------
# Query Item:
#   title                       더블 초코칩 수제 비건쿠키 가나슈 초코 쫀득 꾸덕 결혼 답례품 선물
# purchase_url    https://smartstore.naver.com/veganez/products/...
# Name: 204, dtype: object
# Recommendation Items:
#  Empty DataFrame
# Columns: [title, purchase_url]
# Index: []
#  ------------------------
# Query Item:
#   title             비건이지 수제 쿠키 글루텐프리 무설탕 답례품 퇴사 선물 시보해제 결혼 조공 르뱅 간식
# purchase_url    https://smartstore.naver.com/veganez/products/...
# Name: 205, dtype: object
# Recommendation Items:
#  Empty DataFrame
# Columns: [title, purchase_url]
# Index: []
#  ------------------------
# Query Item:
#   title                                                   로썸 통밀비스코티
# purchase_url    https://smartstore.naver.com/rawsome/products/...
# Name: 206, dtype: object
# Recommendation Items:
#  Empty DataFrame
# Columns: [title, purchase_url]
# Index: []
#  ------------------------
# Query Item:
#   title                                     빵떡집 단백질빵떡이 단백질10g 글루텐프리
# purchase_url    https://smartstore.naver.com/bbangttuk_house/p...
# Name: 207, dtype: object
# Recommendation Items:
#                            title  \
# 142  단백질 디저트 빵떡집 글루텐프리 단백질빵 빵떡이
#
#                                           purchase_url
# 142  https://smartstore.naver.com/bbangttuk_house/p...
#  ------------------------
# Query Item:
#   title                             [소소한 소금빵 4개 세트] 비건빵 100% 건강빵 간식
# purchase_url    https://smartstore.naver.com/thebreadblue/prod...
# Name: 208, dtype: object
# Recommendation Items:
#                                           title  \
# 208            [소소한 소금빵 4개 세트] 비건빵 100% 건강빵 간식
# 138                    소소한 소금빵 비건빵 100% 건강빵 간식
# 46   [클래식 단팥빵 5개 세트] 비건빵 100% 건강빵 영양 간식 더브레드블루
#
#                                           purchase_url
# 208  https://smartstore.naver.com/thebreadblue/prod...
# 138  https://smartstore.naver.com/thebreadblue/prod...
# 46   https://smartstore.naver.com/thebreadblue/prod...
#  ------------------------
# Query Item:
#   title                   [포포브레드] 마들렌 4종 / 쌀 디저트 글루텐프리 노밀가루 비건 베이커리
# purchase_url    https://smartstore.naver.com/forfourbread/prod...
# Name: 209, dtype: object
# Recommendation Items:
#                                                title  \
# 54   [포포브레드] 비건 비스코티 초코 아몬드 / 쌀 디저트 글루텐프리 노밀가루 베이커리
# 89       [포포브레드] 비건 버터바 호지차 / 쌀 디저트 글루텐프리 노밀가루 베이커리
# 100        [포포브레드] 스콘 3종 / 쌀 디저트 글루텐프리 노밀가루 비건 베이커리
#
#                                           purchase_url
# 54   https://smartstore.naver.com/forfourbread/prod...
# 89   https://smartstore.naver.com/forfourbread/prod...
# 100  https://smartstore.naver.com/forfourbread/prod...
#  ------------------------
# Query Item:
#   title                       그림의빵 고단백 저당 크림빵 6개, 100%곡물단백 당뇨와건강몰입점
# purchase_url    https://smartstore.naver.com/grimmsbread/produ...
# Name: 210, dtype: object
# Recommendation Items:
#                                                 title  \
# 210            그림의빵 고단백 저당 크림빵 6개, 100%곡물단백 당뇨와건강몰입점
# 102   그림의빵 저당 고단백 라즈베리 초코 그낭시에 8입, 당뇨와건강몰입점 디저트 휘낭시에
# 177  그림의빵 저당 고단백 라즈베리 초코 그낭시에 16입, 당뇨와건강몰입점 디저트 휘낭시에
#
#                                           purchase_url
# 210  https://smartstore.naver.com/grimmsbread/produ...
# 102  https://smartstore.naver.com/grimmsbread/produ...
# 177  https://smartstore.naver.com/grimmsbread/produ...
#  ------------------------
# 0.6066350710900474

# %%
from collections import Counter
agg_cnt = Counter(rec_list)

# %%
total_rows = 0
matched_rows = 0
for board_id, rec_list in rec_result.items():
    total_rows += len(rec_list)
    for rec in rec_list:
        if rec[0] == rec[1]:
            matched_rows += 1
            print(rec)
# Out:
# (112, 112, 1.0)
# (122, 122, 1.0000000000000002)
# (178, 178, 0.9999999999999998)
# (209, 209, 1.0000000000000002)
# (211, 211, 0.9999999999999999)

# %%
rec_result
# Out:
# defaultdict(list,
#             {1: [(1, 136, 0.6154574548966638),
#               (1, 43, 0.6030226891555273),
#               (1, 27, 0.5698028822981898)],
#              2: [],
#              3: [],
#              4: [],
#              5: [(5, 167, 0.7302967433402215), (5, 18, 0.50709255283711)],
#              6: [(6, 29, 0.7378647873726218),
#               (6, 139, 0.5892556509887895),
#               (6, 45, 0.5555555555555556)],
#              7: [(7, 30, 0.5039526306789696)],
#              8: [(8, 9, 0.5773502691896258),
#               (8, 114, 0.5555555555555556),
#               (8, 209, 0.5555555555555556)],
#              9: [(9, 76, 0.6666666666666669),
#               (9, 98, 0.6666666666666669),
#               (9, 188, 0.6390096504226939)],
#              10: [(10, 69, 0.7161148740394329),
#               (10, 25, 0.5962847939999439),
#               (10, 183, 0.5773502691896257)],
#              11: [(11, 190, 0.801783725737273)],
#              12: [],
#              13: [(13, 176, 0.6227991553292184),
#               (13, 180, 0.6092717958449424),
#               (13, 142, 0.5533715710928596)],
#              14: [(14, 174, 0.502518907629606)],
#              15: [(15, 125, 0.7302967433402215),
#               (15, 34, 0.5477225575051662),
#               (15, 57, 0.5000000000000001)],
#              16: [(16, 123, 0.5658251521157383)],
#              17: [],
#              18: [(18, 163, 0.7171371656006361),
#               (18, 86, 0.7142857142857141),
#               (18, 196, 0.6172133998483676)],
#              19: [(19, 65, 0.5262348115842176)],
#              20: [(20, 122, 1.0000000000000002)],
#              21: [(21, 48, 0.5636018619766344)],
#              22: [],
#              23: [(23, 152, 0.5833333333333335)],
#              24: [],
#              25: [(25, 10, 0.5962847939999439),
#               (25, 69, 0.5604485383178051),
#               (25, 183, 0.5163977794943223)],
#              26: [(26, 69, 0.5384615384615385), (26, 169, 0.5262348115842176)],
#              27: [(27, 136, 0.9258200997725515),
#               (27, 36, 0.8571428571428569),
#               (27, 1, 0.5698028822981898)],
#              28: [],
#              29: [(29, 6, 0.7378647873726218),
#               (29, 136, 0.5163977794943223),
#               (29, 37, 0.50709255283711)],
#              30: [(30, 151, 0.5714285714285713), (30, 7, 0.5039526306789696)],
#              31: [],
#              32: [(32, 142, 0.5380275868489702)],
#              33: [],
#              34: [(34, 57, 0.7302967433402215),
#               (34, 191, 0.7302967433402215),
#               (34, 125, 0.6)],
#              35: [],
#              36: [(36, 136, 0.9258200997725515),
#               (36, 27, 0.8571428571428569),
#               (36, 1, 0.5698028822981898)],
#              37: [(37, 77, 0.7715167498104596),
#               (37, 115, 0.7715167498104596),
#               (37, 128, 0.7715167498104596)],
#              38: [],
#              39: [],
#              40: [(40, 54, 0.6726727939963125)],
#              41: [(41, 112, 1.0)],
#              42: [(42, 194, 0.6153846153846154),
#               (42, 198, 0.5728918992315463)],
#              43: [(43, 1, 0.6030226891555273),
#               (43, 136, 0.5443310539518174),
#               (43, 27, 0.5039526306789696)],
#              44: [],
#              45: [(45, 92, 0.8040302522073697),
#               (45, 47, 0.7698003589195012),
#               (45, 139, 0.7071067811865475)],
#              46: [],
#              47: [(47, 92, 0.957427107756338),
#               (47, 45, 0.7698003589195012),
#               (47, 49, 0.7500000000000002)],
#              48: [(48, 21, 0.5636018619766344), (48, 177, 0.5009794328681195)],
#              49: [(49, 47, 0.7500000000000002),
#               (49, 92, 0.6963106238227913),
#               (49, 114, 0.6735753140545635)],
#              50: [],
#              51: [],
#              52: [(52, 196, 0.9258200997725515),
#               (52, 18, 0.5714285714285713),
#               (52, 86, 0.5714285714285713)],
#              53: [],
#              54: [(54, 40, 0.6726727939963125)],
#              55: [(55, 90, 0.7302967433402215),
#               (55, 101, 0.7302967433402215),
#               (55, 61, 0.6963106238227913)],
#              56: [],
#              57: [(57, 34, 0.7302967433402215),
#               (57, 191, 0.6666666666666669),
#               (57, 125, 0.5477225575051662)],
#              58: [],
#              59: [(59, 84, 0.7715167498104596),
#               (59, 108, 0.7715167498104596),
#               (59, 125, 0.5163977794943223)],
#              60: [(60, 151, 0.545544725589981),
#               (60, 140, 0.5103103630798288),
#               (60, 144, 0.5103103630798288)],
#              61: [(61, 90, 0.762770071396474),
#               (61, 101, 0.762770071396474),
#               (61, 131, 0.7272727272727274)],
#              62: [(62, 34, 0.5477225575051662)],
#              63: [(63, 95, 0.618589574131742)],
#              64: [],
#              65: [(65, 19, 0.5262348115842176)],
#              66: [(66, 96, 0.8703882797784891), (66, 9, 0.5000000000000001)],
#              67: [(67, 177, 0.9095085938862489),
#               (67, 157, 0.5669467095138409),
#               (67, 81, 0.5533985905294664)],
#              68: [(68, 193, 0.8620689655172411)],
#              69: [(69, 10, 0.7161148740394329),
#               (69, 25, 0.5604485383178051),
#               (69, 26, 0.5384615384615385)],
#              70: [],
#              71: [],
#              72: [(72, 201, 0.583383351196948), (72, 110, 0.5520524474738834)],
#              73: [(73, 189, 0.7216878364870323),
#               (73, 141, 0.6666666666666669),
#               (73, 163, 0.6454972243679029)],
#              74: [],
#              75: [(75, 179, 0.6299407883487119),
#               (75, 187, 0.6299407883487119)],
#              76: [(76, 77, 0.7500000000000002),
#               (76, 115, 0.7500000000000002),
#               (76, 128, 0.7500000000000002)],
#              77: [(77, 197, 0.8807048459279794),
#               (77, 115, 0.8333333333333336),
#               (77, 128, 0.8333333333333336)],
#              78: [(78, 45, 0.5892556509887895),
#               (78, 92, 0.533001790889026),
#               (78, 47, 0.5103103630798288)],
#              79: [(79, 121, 0.7559289460184544),
#               (79, 34, 0.50709255283711),
#               (79, 125, 0.50709255283711)],
#              80: [],
#              81: [(81, 177, 0.6135719910778964), (81, 67, 0.5533985905294664)],
#              82: [(82, 118, 0.588348405414552), (82, 174, 0.5017452060042545)],
#              83: [],
#              84: [(84, 108, 0.8571428571428571), (84, 59, 0.7715167498104596)],
#              85: [(85, 202, 0.5720775535473555)],
#              86: [(86, 163, 0.8366600265340755),
#               (86, 18, 0.7142857142857141),
#               (86, 156, 0.7142857142857141)],
#              87: [],
#              88: [],
#              89: [],
#              90: [(90, 101, 0.7999999999999999),
#               (90, 61, 0.762770071396474),
#               (90, 131, 0.762770071396474)],
#              91: [],
#              92: [(92, 47, 0.957427107756338),
#               (92, 45, 0.8040302522073697),
#               (92, 49, 0.6963106238227913)],
#              93: [(93, 113, 0.6708203932499369)],
#              94: [],
#              95: [(95, 63, 0.618589574131742), (95, 203, 0.5292561240249631)],
#              96: [(96, 66, 0.8703882797784891)],
#              97: [(97, 103, 0.9309493362512627),
#               (97, 178, 0.9309493362512627),
#               (97, 111, 0.5520524474738834)],
#              98: [(98, 9, 0.6666666666666669),
#               (98, 188, 0.6390096504226939),
#               (98, 76, 0.5833333333333335)],
#              99: [],
#              100: [],
#              101: [(101, 90, 0.7999999999999999),
#               (101, 61, 0.762770071396474),
#               (101, 131, 0.762770071396474)],
#              102: [],
#              103: [(103, 178, 0.9999999999999998),
#               (103, 97, 0.9309493362512627),
#               (103, 111, 0.592999453328881)],
#              104: [(104, 86, 0.5698028822981898),
#               (104, 156, 0.5698028822981898)],
#              105: [(105, 195, 0.5457051563317493)],
#              106: [],
#              107: [],
#              108: [(108, 84, 0.8571428571428571),
#               (108, 59, 0.7715167498104596)],
#              109: [(109, 76, 0.6963106238227913),
#               (109, 92, 0.6363636363636365),
#               (109, 47, 0.6092717958449424)],
#              110: [(110, 201, 0.5636018619766344),
#               (110, 72, 0.5520524474738834)],
#              111: [(111, 211, 0.9999999999999999),
#               (111, 103, 0.592999453328881),
#               (111, 178, 0.592999453328881)],
#              112: [(112, 112, 1.0)],
#              113: [(113, 93, 0.6708203932499369),
#               (113, 90, 0.5590169943749475),
#               (113, 101, 0.5590169943749475)],
#              114: [(114, 209, 1.0000000000000002),
#               (114, 139, 0.9428090415820634),
#               (114, 47, 0.6735753140545635)],
#              115: [(115, 77, 0.8333333333333336),
#               (115, 128, 0.8333333333333336),
#               (115, 197, 0.8006407690254358)],
#              116: [(116, 73, 0.5000000000000001)],
#              117: [],
#              118: [(118, 82, 0.588348405414552),
#               (118, 202, 0.533001790889026)],
#              119: [(119, 176, 0.5063696835418331)],
#              120: [],
#              121: [(121, 79, 0.7559289460184544)],
#              122: [(122, 122, 1.0000000000000002)],
#              123: [(123, 16, 0.5658251521157383)],
#              124: [(124, 188, 0.5720775535473555),
#               (124, 161, 0.533001790889026)],
#              125: [(125, 15, 0.7302967433402215),
#               (125, 34, 0.6),
#               (125, 57, 0.5477225575051662)],
#              126: [(126, 157, 0.6546536707079772),
#               (126, 186, 0.6123724356957946),
#               (126, 86, 0.545544725589981)],
#              127: [],
#              128: [(128, 77, 0.8333333333333336),
#               (128, 115, 0.8333333333333336),
#               (128, 197, 0.8006407690254358)],
#              129: [],
#              130: [],
#              131: [(131, 90, 0.762770071396474),
#               (131, 101, 0.762770071396474),
#               (131, 61, 0.7272727272727274)],
#              132: [(132, 136, 0.5443310539518174),
#               (132, 27, 0.5039526306789696),
#               (132, 36, 0.5039526306789696)],
#              133: [(133, 113, 0.533001790889026)],
#              134: [(134, 192, 0.5103103630798288)],
#              135: [],
#              136: [(136, 27, 0.9258200997725515),
#               (136, 36, 0.9258200997725515),
#               (136, 1, 0.6154574548966638)],
#              137: [(137, 154, 0.5773502691896258)],
#              138: [],
#              139: [(139, 114, 0.9428090415820634),
#               (139, 209, 0.9428090415820634),
#               (139, 45, 0.7071067811865475)],
#              140: [(140, 144, 0.7499999999999999),
#               (140, 163, 0.6708203932499369),
#               (140, 86, 0.6681531047810608)],
#              141: [(141, 73, 0.6666666666666669),
#               (141, 140, 0.5773502691896258),
#               (141, 144, 0.5773502691896258)],
#              142: [(142, 86, 0.6069769786668839),
#               (142, 13, 0.5533715710928596),
#               (142, 32, 0.5380275868489702)],
#              143: [(143, 208, 0.6923076923076923)],
#              144: [(144, 140, 0.7499999999999999),
#               (144, 163, 0.6708203932499369),
#               (144, 86, 0.6681531047810608)],
#              145: [],
#              146: [],
#              147: [],
#              148: [],
#              149: [],
#              150: [],
#              151: [(151, 156, 0.7142857142857141),
#               (151, 140, 0.6681531047810608),
#               (151, 144, 0.6681531047810608)],
#              152: [(152, 23, 0.5833333333333335)],
#              153: [(153, 190, 0.5241424183609591)],
#              154: [(154, 137, 0.5773502691896258)],
#              155: [(155, 192, 0.6390096504226939)],
#              156: [(156, 163, 0.7171371656006361),
#               (156, 86, 0.7142857142857141),
#               (156, 151, 0.7142857142857141)],
#              157: [(157, 126, 0.6546536707079772),
#               (157, 67, 0.5669467095138409),
#               (157, 177, 0.5500190982169267)],
#              158: [],
#              159: [],
#              160: [],
#              161: [(161, 188, 0.6708203932499369),
#               (161, 124, 0.533001790889026),
#               (161, 9, 0.5103103630798288)],
#              162: [],
#              163: [(163, 86, 0.8366600265340755),
#               (163, 18, 0.7171371656006361),
#               (163, 156, 0.7171371656006361)],
#              164: [(164, 181, 0.9285714285714285),
#               (164, 90, 0.5916079783099616),
#               (164, 101, 0.5916079783099616)],
#              165: [(165, 73, 0.5163977794943223)],
#              166: [(166, 76, 0.6963106238227913),
#               (166, 128, 0.6963106238227913),
#               (166, 139, 0.6396021490668312)],
#              167: [(167, 5, 0.7302967433402215)],
#              168: [],
#              169: [(169, 26, 0.5262348115842176)],
#              170: [],
#              171: [(171, 34, 0.6), (171, 57, 0.5477225575051662)],
#              172: [(172, 55, 0.6495190528383291),
#               (172, 90, 0.6324555320336759),
#               (172, 101, 0.6324555320336759)],
#              173: [],
#              174: [(174, 14, 0.502518907629606),
#               (174, 82, 0.5017452060042545)],
#              175: [],
#              176: [(176, 13, 0.6227991553292184),
#               (176, 180, 0.521749194749951),
#               (176, 119, 0.5063696835418331)],
#              177: [(177, 67, 0.9095085938862489),
#               (177, 81, 0.6135719910778964),
#               (177, 157, 0.5500190982169267)],
#              178: [(178, 178, 0.9999999999999998),
#               (178, 97, 0.9309493362512627),
#               (178, 111, 0.592999453328881)],
#              179: [(179, 75, 0.6299407883487119),
#               (179, 187, 0.5555555555555556)],
#              180: [(180, 13, 0.6092717958449424),
#               (180, 142, 0.5298129428260175),
#               (180, 176, 0.521749194749951)],
#              181: [(181, 164, 0.9285714285714285),
#               (181, 90, 0.6761234037828132),
#               (181, 101, 0.6761234037828132)],
#              182: [],
#              183: [(183, 10, 0.5773502691896257),
#               (183, 25, 0.5163977794943223)],
#              184: [],
#              185: [],
#              186: [(186, 126, 0.6123724356957946)],
#              187: [(187, 75, 0.6299407883487119),
#               (187, 179, 0.5555555555555556)],
#              188: [(188, 76, 0.7302967433402215),
#               (188, 77, 0.7302967433402215),
#               (188, 115, 0.7302967433402215)],
#              189: [(189, 73, 0.7216878364870323),
#               (189, 141, 0.5773502691896258),
#               (189, 163, 0.5590169943749475)],
#              190: [(190, 11, 0.801783725737273),
#               (190, 153, 0.5241424183609591)],
#              191: [(191, 34, 0.7302967433402215),
#               (191, 57, 0.6666666666666669),
#               (191, 125, 0.5477225575051662)],
#              192: [(192, 155, 0.6390096504226939),
#               (192, 163, 0.5477225575051662),
#               (192, 86, 0.545544725589981)],
#              193: [(193, 68, 0.8620689655172411)],
#              194: [(194, 198, 0.9309493362512627),
#               (194, 42, 0.6153846153846154),
#               (194, 111, 0.5188745216627709)],
#              195: [(195, 105, 0.5457051563317493)],
#              196: [(196, 52, 0.9258200997725515),
#               (196, 18, 0.6172133998483676),
#               (196, 86, 0.6172133998483676)],
#              197: [(197, 77, 0.8807048459279794),
#               (197, 115, 0.8006407690254358),
#               (197, 128, 0.8006407690254358)],
#              198: [(198, 194, 0.9309493362512627),
#               (198, 42, 0.5728918992315463),
#               (198, 111, 0.5520524474738834)],
#              199: [],
#              200: [],
#              201: [(201, 72, 0.583383351196948),
#               (201, 110, 0.5636018619766344)],
#              202: [(202, 85, 0.5720775535473555),
#               (202, 118, 0.533001790889026)],
#              203: [(203, 95, 0.5292561240249631)],
#              204: [],
#              205: [],
#              206: [],
#              207: [],
#              208: [(208, 143, 0.6923076923076923)],
#              209: [(209, 209, 1.0000000000000002),
#               (209, 139, 0.9428090415820634),
#               (209, 47, 0.6735753140545635)],
#              210: [(210, 55, 0.6943650748294137),
#               (210, 90, 0.6761234037828132),
#               (210, 101, 0.6761234037828132)],
#              211: [(211, 211, 0.9999999999999999),
#               (211, 103, 0.592999453328881),
#               (211, 178, 0.592999453328881)]})

# %%
agg_df = pd.DataFrame.from_dict(agg_cnt, orient='index').reset_index()
agg_df.columns = ['id', 'count']
fig = plt.figure(figsize=(10, 6))
plt.bar(agg_df['id'], agg_df['count'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 3
#       1 agg_df = pd.DataFrame.from_dict(agg_cnt, orient='index').reset_index()
#       2 agg_df.columns = ['id', 'count']
# ----> 3 fig = plt.figure(figsize=(10, 6))
#       4 plt.bar(agg_df['id'], agg_df['count'])
#
# NameError: name 'plt' is not defined
